# %% [markdown]
# # Association Rule - Apriori and ECLAT
#
# Training association rule models (Apriori and ECLAT) to find the most related items bought by customers of a french supermarket during a week. All 7501 lines of the dataset represent items bought by an unique customer, during this week.
#
# This algorithm associate products preferences by most of the customers and can be used to generate products recommendation and help on displaying products strategy.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Data Loading
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# Adding all customers into a list of lists
transactions = []
for i in range(0, len(dataset)):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
dataset.head(20)
# Out:
#                    0             1              2                 3   \
# 0              shrimp       almonds        avocado    vegetables mix
# 1             burgers     meatballs           eggs               NaN
# 2             chutney           NaN            NaN               NaN
# 3              turkey       avocado            NaN               NaN
# 4       mineral water          milk     energy bar  whole wheat rice
# 5      low fat yogurt           NaN            NaN               NaN
# 6   whole wheat pasta  french fries            NaN               NaN
# 7                soup   light cream        shallot               NaN
# 8   frozen vegetables     spaghetti      green tea               NaN
# 9        french fries           NaN            NaN               NaN
# 10               eggs      pet food            NaN               NaN
# 11            cookies           NaN            NaN               NaN
# 12             turkey       burgers  mineral water              eggs
# 13          spaghetti     champagne        cookies               NaN
# 14      mineral water        salmon            NaN               NaN
# 15      mineral water           NaN            NaN               NaN
# 16             shrimp     chocolate        chicken             honey
# 17             turkey          eggs            NaN               NaN
# 18             turkey    fresh tuna       tomatoes         spaghetti
# 19          meatballs          milk          honey      french fries
#
#                4                 5               6               7   \
# 0    green grapes  whole weat flour            yams  cottage cheese
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4       green tea               NaN             NaN             NaN
# 5             NaN               NaN             NaN             NaN
# 6             NaN               NaN             NaN             NaN
# 7             NaN               NaN             NaN             NaN
# 8             NaN               NaN             NaN             NaN
# 9             NaN               NaN             NaN             NaN
# 10            NaN               NaN             NaN             NaN
# 11            NaN               NaN             NaN             NaN
# 12    cooking oil               NaN             NaN             NaN
# 13            NaN               NaN             NaN             NaN
# 14            NaN               NaN             NaN             NaN
# 15            NaN               NaN             NaN             NaN
# 16            oil       cooking oil  low fat yogurt             NaN
# 17            NaN               NaN             NaN             NaN
# 18  mineral water         black tea          salmon            eggs
# 19    protein bar               NaN             NaN             NaN
#
#               8                     9               10         11     12  \
# 0   energy drink          tomato juice  low fat yogurt  green tea  honey
# 1            NaN                   NaN             NaN        NaN    NaN
# 2            NaN                   NaN             NaN        NaN    NaN
# 3            NaN                   NaN             NaN        NaN    NaN
# 4            NaN                   NaN             NaN        NaN    NaN
# 5            NaN                   NaN             NaN        NaN    NaN
# 6            NaN                   NaN             NaN        NaN    NaN
# 7            NaN                   NaN             NaN        NaN    NaN
# 8            NaN                   NaN             NaN        NaN    NaN
# 9            NaN                   NaN             NaN        NaN    NaN
# 10           NaN                   NaN             NaN        NaN    NaN
# 11           NaN                   NaN             NaN        NaN    NaN
# 12           NaN                   NaN             NaN        NaN    NaN
# 13           NaN                   NaN             NaN        NaN    NaN
# 14           NaN                   NaN             NaN        NaN    NaN
# 15           NaN                   NaN             NaN        NaN    NaN
# 16           NaN                   NaN             NaN        NaN    NaN
# 17           NaN                   NaN             NaN        NaN    NaN
# 18       chicken  extra dark chocolate             NaN        NaN    NaN
# 19           NaN                   NaN             NaN        NaN    NaN
#
#        13             14      15                 16               17       18  \
# 0   salad  mineral water  salmon  antioxydant juice  frozen smoothie  spinach
# 1     NaN            NaN     NaN                NaN              NaN      NaN
# 2     NaN            NaN     NaN                NaN              NaN      NaN
# 3     NaN            NaN     NaN                NaN              NaN      NaN
# 4     NaN            NaN     NaN                NaN              NaN      NaN
# 5     NaN            NaN     NaN                NaN              NaN      NaN
# 6     NaN            NaN     NaN                NaN              NaN      NaN
# 7     NaN            NaN     NaN                NaN              NaN      NaN
# 8     NaN            NaN     NaN                NaN              NaN      NaN
# 9     NaN            NaN     NaN                NaN              NaN      NaN
# 10    NaN            NaN     NaN                NaN              NaN      NaN
# 11    NaN            NaN     NaN                NaN              NaN      NaN
# 12    NaN            NaN     NaN                NaN              NaN      NaN
# 13    NaN            NaN     NaN                NaN              NaN      NaN
# 14    NaN            NaN     NaN                NaN              NaN      NaN
# 15    NaN            NaN     NaN                NaN              NaN      NaN
# 16    NaN            NaN     NaN                NaN              NaN      NaN
# 17    NaN            NaN     NaN                NaN              NaN      NaN
# 18    NaN            NaN     NaN                NaN              NaN      NaN
# 19    NaN            NaN     NaN                NaN              NaN      NaN
#
#            19
# 0   olive oil
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %% [markdown]
# ### Apriori implementation using apyori library
# source: https://github.com/ymoch/apyori
#
# The output of this part is to see which are the products that used to be more bought in combination compared to other combinations using apriori algorithm.
#
# We will put some transformations to fit on dataframes and to make the visualization easier.

# %%
# Inspecting elements
transactions[:3]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
# Training Apriori on the dataset
# The hyperparameters choosen on this training are:
# min_support = items bought more than 3 times a day * 7 days (week) / 7500 customers = 0.0028
# min_confidence: at least 20%, min_lift = minimum of 3 (less than that is too low)
# min_length: we want at least 2 items to be associated. No point in having a single item in the result

from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
# Visualising the results
results = list(rules)

# %%
lift = []
association = []
for i in range (0, len(results)):
    lift.append(results[:len(results)][i][2][0][3])
    association.append(list(results[:len(results)][i][0]))

# %% [markdown]
# ### Visualizing results in a dataframe

# %%
rank = pd.DataFrame([association, lift]).transpose()
rank.columns = ['Association', 'Lift']

# %%
# Show top 10 higher lift scores
rank.sort_values('Lift', ascending=False).head(10)
# Out:
#                                            Association     Lift
# 128  [mineral water, whole wheat pasta, nan, olive ...  6.11586
# 58       [mineral water, whole wheat pasta, olive oil]  6.11586
# 96      [mineral water, soup, milk, frozen vegetables]  5.48441
# 146  [soup, milk, frozen vegetables, mineral water,...  5.48441
# 28                         [fromage blanc, honey, nan]  5.16427
# 3                               [fromage blanc, honey]  5.16427
# 16                         [nan, chicken, light cream]  4.84395
# 0                               [chicken, light cream]  4.84395
# 2                                    [escalope, pasta]  4.70081
# 26                              [escalope, nan, pasta]  4.70081

# %% [markdown]
# By the study, "olive oil, whole wheat pasta, mineral water" are the most commom combined items from this week for the supermarket in question.

# %% [markdown]
# ## ECLAT Implementation
#
# This is an implementation of the ECLAT code by hand. It calculate the pairs that have been bought more frequently comparing to other pairs. At the end, we expect to see what is the most common combination of products during the week.
#
# An extension of the code can calculate the three most common combination, 4, and so on.

# %% [markdown]
# #### Getting the list of products bought this week by all customers

# %%
# Putting all transactions in a single list
itens = []
for i in range(0, len(transactions)):
    itens.extend(transactions[i])

# Finding unique items from transactions and removing nan
uniqueItems = list(set(itens))
uniqueItems.remove('nan')

# %%
uniqueItems
# Out:
# ['fresh tuna',
#  'strong cheese',
#  'meatballs',
#  'low fat yogurt',
#  'magazines',
#  'shampoo',
#  'mint',
#  'candy bars',
#  'tomato juice',
#  'chocolate',
#  'corn',
#  'green tea',
#  'tomatoes',
#  'body spray',
#  'gluten free bar',
#  'champagne',
#  'burger sauce',
#  'strawberries',
#  'fromage blanc',
#  'salt',
#  'mayonnaise',
#  'cookies',
#  'cooking oil',
#  'barbecue sauce',
#  'bacon',
#  'shrimp',
#  'cider',
#  'yogurt cake',
#  'melons',
#  'ketchup',
#  'spaghetti',
#  'muffins',
#  'ground beef',
#  'asparagus',
#  'cauliflower',
#  'energy drink',
#  'dessert wine',
#  'chutney',
#  'extra dark chocolate',
#  'french wine',
#  'pet food',
#  'pepper',
#  'french fries',
#  'antioxydant juice',
#  'spinach',
#  'oatmeal',
#  'sandwich',
#  'mashed potato',
#  'whole wheat rice',
#  'energy bar',
#  'hot dogs',
#  'shallot',
#  'tomato sauce',
#  'frozen smoothie',
#  'rice',
#  'bramble',
#  'pickles',
#  'soda',
#  'hand protein bar',
#  'clothes accessories',
#  'salad',
#  'oil',
#  'green grapes',
#  'brownies',
#  'soup',
#  'eggplant',
#  'cottage cheese',
#  'whole wheat pasta',
#  'napkins',
#  'mushroom cream sauce',
#  'mineral water',
#  'turkey',
#  'babies food',
#  'flax seed',
#  'salmon',
#  'pancakes',
#  'escalope',
#  'honey',
#  'cereals',
#  'white wine',
#  'tea',
#  'vegetables mix',
#  'milk',
#  'mint green tea',
#  ' asparagus',
#  'frozen vegetables',
#  'olive oil',
#  'zucchini',
#  'carrots',
#  'red wine',
#  'nonfat milk',
#  'ham',
#  'blueberries',
#  'gums',
#  'chili',
#  'pasta',
#  'herb & pepper',
#  'green beans',
#  'cream',
#  'fresh bread',
#  'grated cheese',
#  'avocado',
#  'toothpaste',
#  'whole weat flour',
#  'eggs',
#  'bug spray',
#  'parmesan cheese',
#  'yams',
#  'almonds',
#  'chicken',
#  'butter',
#  'water spray',
#  'light cream',
#  'light mayo',
#  'chocolate bread',
#  'cake',
#  'protein bar',
#  'black tea',
#  'sparkling water',
#  'burgers']

# %% [markdown]
# #### Creating combinations with the items - pairs

# %%
pair = []
for j in range(0, len(uniqueItems)):
    k = 1;
    while k <= len(uniqueItems):
        try:
            pair.append([uniqueItems[j], uniqueItems[j+k]])
        except IndexError:
            pass
        k = k + 1;

# %%
pair
# Out:
# [['fresh tuna', 'strong cheese'],
#  ['fresh tuna', 'meatballs'],
#  ['fresh tuna', 'low fat yogurt'],
#  ['fresh tuna', 'magazines'],
#  ['fresh tuna', 'shampoo'],
#  ['fresh tuna', 'mint'],
#  ['fresh tuna', 'candy bars'],
#  ['fresh tuna', 'tomato juice'],
#  ['fresh tuna', 'chocolate'],
#  ['fresh tuna', 'corn'],
#  ['fresh tuna', 'green tea'],
#  ['fresh tuna', 'tomatoes'],
#  ['fresh tuna', 'body spray'],
#  ['fresh tuna', 'gluten free bar'],
#  ['fresh tuna', 'champagne'],
#  ['fresh tuna', 'burger sauce'],
#  ['fresh tuna', 'strawberries'],
#  ['fresh tuna', 'fromage blanc'],
#  ['fresh tuna', 'salt'],
#  ['fresh tuna', 'mayonnaise'],
#  ['fresh tuna', 'cookies'],
#  ['fresh tuna', 'cooking oil'],
#  ['fresh tuna', 'barbecue sauce'],
#  ['fresh tuna', 'bacon'],
#  ['fresh tuna', 'shrimp'],
#  ['fresh tuna', 'cider'],
#  ['fresh tuna', 'yogurt cake'],
#  ['fresh tuna', 'melons'],
#  ['fresh tuna', 'ketchup'],
#  ['fresh tuna', 'spaghetti'],
#  ['fresh tuna', 'muffins'],
#  ['fresh tuna', 'ground beef'],
#  ['fresh tuna', 'asparagus'],
#  ['fresh tuna', 'cauliflower'],
#  ['fresh tuna', 'energy drink'],
#  ['fresh tuna', 'dessert wine'],
#  ['fresh tuna', 'chutney'],
#  ['fresh tuna', 'extra dark chocolate'],
#  ['fresh tuna', 'french wine'],
#  ['fresh tuna', 'pet food'],
#  ['fresh tuna', 'pepper'],
#  ['fresh tuna', 'french fries'],
#  ['fresh tuna', 'antioxydant juice'],
#  ['fresh tuna', 'spinach'],
#  ['fresh tuna', 'oatmeal'],
#  ['fresh tuna', 'sandwich'],
#  ['fresh tuna', 'mashed potato'],
#  ['fresh tuna', 'whole wheat rice'],
#  ['fresh tuna', 'energy bar'],
#  ['fresh tuna', 'hot dogs'],
#  ['fresh tuna', 'shallot'],
#  ['fresh tuna', 'tomato sauce'],
#  ['fresh tuna', 'frozen smoothie'],
#  ['fresh tuna', 'rice'],
#  ['fresh tuna', 'bramble'],
#  ['fresh tuna', 'pickles'],
#  ['fresh tuna', 'soda'],
#  ['fresh tuna', 'hand protein bar'],
#  ['fresh tuna', 'clothes accessories'],
#  ['fresh tuna', 'salad'],
#  ['fresh tuna', 'oil'],
#  ['fresh tuna', 'green grapes'],
#  ['fresh tuna', 'brownies'],
#  ['fresh tuna', 'soup'],
#  ['fresh tuna', 'eggplant'],
#  ['fresh tuna', 'cottage cheese'],
#  ['fresh tuna', 'whole wheat pasta'],
#  ['fresh tuna', 'napkins'],
#  ['fresh tuna', 'mushroom cream sauce'],
#  ['fresh tuna', 'mineral water'],
#  ['fresh tuna', 'turkey'],
#  ['fresh tuna', 'babies food'],
#  ['fresh tuna', 'flax seed'],
#  ['fresh tuna', 'salmon'],
#  ['fresh tuna', 'pancakes'],
#  ['fresh tuna', 'escalope'],
#  ['fresh tuna', 'honey'],
#  ['fresh tuna', 'cereals'],
#  ['fresh tuna', 'white wine'],
#  ['fresh tuna', 'tea'],
#  ['fresh tuna', 'vegetables mix'],
#  ['fresh tuna', 'milk'],
#  ['fresh tuna', 'mint green tea'],
#  ['fresh tuna', ' asparagus'],
#  ['fresh tuna', 'frozen vegetables'],
#  ['fresh tuna', 'olive oil'],
#  ['fresh tuna', 'zucchini'],
#  ['fresh tuna', 'carrots'],
#  ['fresh tuna', 'red wine'],
#  ['fresh tuna', 'nonfat milk'],
#  ['fresh tuna', 'ham'],
#  ['fresh tuna', 'blueberries'],
#  ['fresh tuna', 'gums'],
#  ['fresh tuna', 'chili'],
#  ['fresh tuna', 'pasta'],
#  ['fresh tuna', 'herb & pepper'],
#  ['fresh tuna', 'green beans'],
#  ['fresh tuna', 'cream'],
#  ['fresh tuna', 'fresh bread'],
#  ['fresh tuna', 'grated cheese'],
#  ['fresh tuna', 'avocado'],
#  ['fresh tuna', 'toothpaste'],
#  ['fresh tuna', 'whole weat flour'],
#  ['fresh tuna', 'eggs'],
#  ['fresh tuna', 'bug spray'],
#  ['fresh tuna', 'parmesan cheese'],
#  ['fresh tuna', 'yams'],
#  ['fresh tuna', 'almonds'],
#  ['fresh tuna', 'chicken'],
#  ['fresh tuna', 'butter'],
#  ['fresh tuna', 'water spray'],
#  ['fresh tuna', 'light cream'],
#  ['fresh tuna', 'light mayo'],
#  ['fresh tuna', 'chocolate bread'],
#  ['fresh tuna', 'cake'],
#  ['fresh tuna', 'protein bar'],
#  ['fresh tuna', 'black tea'],
#  ['fresh tuna', 'sparkling water'],
#  ['fresh tuna', 'burgers'],
#  ['strong cheese', 'meatballs'],
#  ['strong cheese', 'low fat yogurt'],
#  ['strong cheese', 'magazines'],
#  ['strong cheese', 'shampoo'],
#  ['strong cheese', 'mint'],
#  ['strong cheese', 'candy bars'],
#  ['strong cheese', 'tomato juice'],
#  ['strong cheese', 'chocolate'],
#  ['strong cheese', 'corn'],
#  ['strong cheese', 'green tea'],
#  ['strong cheese', 'tomatoes'],
#  ['strong cheese', 'body spray'],
#  ['strong cheese', 'gluten free bar'],
#  ['strong cheese', 'champagne'],
#  ['strong cheese', 'burger sauce'],
#  ['strong cheese', 'strawberries'],
#  ['strong cheese', 'fromage blanc'],
#  ['strong cheese', 'salt'],
#  ['strong cheese', 'mayonnaise'],
#  ['strong cheese', 'cookies'],
#  ['strong cheese', 'cooking oil'],
#  ['strong cheese', 'barbecue sauce'],
#  ['strong cheese', 'bacon'],
#  ['strong cheese', 'shrimp'],
#  ['strong cheese', 'cider'],
#  ['strong cheese', 'yogurt cake'],
#  ['strong cheese', 'melons'],
#  ['strong cheese', 'ketchup'],
#  ['strong cheese', 'spaghetti'],
#  ['strong cheese', 'muffins'],
#  ['strong cheese', 'ground beef'],
#  ['strong cheese', 'asparagus'],
#  ['strong cheese', 'cauliflower'],
#  ['strong cheese', 'energy drink'],
#  ['strong cheese', 'dessert wine'],
#  ['strong cheese', 'chutney'],
#  ['strong cheese', 'extra dark chocolate'],
#  ['strong cheese', 'french wine'],
#  ['strong cheese', 'pet food'],
#  ['strong cheese', 'pepper'],
#  ['strong cheese', 'french fries'],
#  ['strong cheese', 'antioxydant juice'],
#  ['strong cheese', 'spinach'],
#  ['strong cheese', 'oatmeal'],
#  ['strong cheese', 'sandwich'],
#  ['strong cheese', 'mashed potato'],
#  ['strong cheese', 'whole wheat rice'],
#  ['strong cheese', 'energy bar'],
#  ['strong cheese', 'hot dogs'],
#  ['strong cheese', 'shallot'],
#  ['strong cheese', 'tomato sauce'],
#  ['strong cheese', 'frozen smoothie'],
#  ['strong cheese', 'rice'],
#  ['strong cheese', 'bramble'],
#  ['strong cheese', 'pickles'],
#  ['strong cheese', 'soda'],
#  ['strong cheese', 'hand protein bar'],
#  ['strong cheese', 'clothes accessories'],
#  ['strong cheese', 'salad'],
#  ['strong cheese', 'oil'],
#  ['strong cheese', 'green grapes'],
#  ['strong cheese', 'brownies'],
#  ['strong cheese', 'soup'],
#  ['strong cheese', 'eggplant'],
#  ['strong cheese', 'cottage cheese'],
#  ['strong cheese', 'whole wheat pasta'],
#  ['strong cheese', 'napkins'],
#  ['strong cheese', 'mushroom cream sauce'],
#  ['strong cheese', 'mineral water'],
#  ['strong cheese', 'turkey'],
#  ['strong cheese', 'babies food'],
#  ['strong cheese', 'flax seed'],
#  ['strong cheese', 'salmon'],
#  ['strong cheese', 'pancakes'],
#  ['strong cheese', 'escalope'],
#  ['strong cheese', 'honey'],
#  ['strong cheese', 'cereals'],
#  ['strong cheese', 'white wine'],
#  ['strong cheese', 'tea'],
#  ['strong cheese', 'vegetables mix'],
#  ['strong cheese', 'milk'],
#  ['strong cheese', 'mint green tea'],
#  ['strong cheese', ' asparagus'],
#  ['strong cheese', 'frozen vegetables'],
#  ['strong cheese', 'olive oil'],
#  ['strong cheese', 'zucchini'],
#  ['strong cheese', 'carrots'],
#  ['strong cheese', 'red wine'],
#  ['strong cheese', 'nonfat milk'],
#  ['strong cheese', 'ham'],
#  ['strong cheese', 'blueberries'],
#  ['strong cheese', 'gums'],
#  ['strong cheese', 'chili'],
#  ['strong cheese', 'pasta'],
#  ['strong cheese', 'herb & pepper'],
#  ['strong cheese', 'green beans'],
#  ['strong cheese', 'cream'],
#  ['strong cheese', 'fresh bread'],
#  ['strong cheese', 'grated cheese'],
#  ['strong cheese', 'avocado'],
#  ['strong cheese', 'toothpaste'],
#  ['strong cheese', 'whole weat flour'],
#  ['strong cheese', 'eggs'],
#  ['strong cheese', 'bug spray'],
#  ['strong cheese', 'parmesan cheese'],
#  ['strong cheese', 'yams'],
#  ['strong cheese', 'almonds'],
#  ['strong cheese', 'chicken'],
#  ['strong cheese', 'butter'],
#  ['strong cheese', 'water spray'],
#  ['strong cheese', 'light cream'],
#  ['strong cheese', 'light mayo'],
#  ['strong cheese', 'chocolate bread'],
#  ['strong cheese', 'cake'],
#  ['strong cheese', 'protein bar'],
#  ['strong cheese', 'black tea'],
#  ['strong cheese', 'sparkling water'],
#  ['strong cheese', 'burgers'],
#  ['meatballs', 'low fat yogurt'],
#  ['meatballs', 'magazines'],
#  ['meatballs', 'shampoo'],
#  ['meatballs', 'mint'],
#  ['meatballs', 'candy bars'],
#  ['meatballs', 'tomato juice'],
#  ['meatballs', 'chocolate'],
#  ['meatballs', 'corn'],
#  ['meatballs', 'green tea'],
#  ['meatballs', 'tomatoes'],
#  ['meatballs', 'body spray'],
#  ['meatballs', 'gluten free bar'],
#  ['meatballs', 'champagne'],
#  ['meatballs', 'burger sauce'],
#  ['meatballs', 'strawberries'],
#  ['meatballs', 'fromage blanc'],
#  ['meatballs', 'salt'],
#  ['meatballs', 'mayonnaise'],
#  ['meatballs', 'cookies'],
#  ['meatballs', 'cooking oil'],
#  ['meatballs', 'barbecue sauce'],
#  ['meatballs', 'bacon'],
#  ['meatballs', 'shrimp'],
#  ['meatballs', 'cider'],
#  ['meatballs', 'yogurt cake'],
#  ['meatballs', 'melons'],
#  ['meatballs', 'ketchup'],
#  ['meatballs', 'spaghetti'],
#  ['meatballs', 'muffins'],
#  ['meatballs', 'ground beef'],
#  ['meatballs', 'asparagus'],
#  ['meatballs', 'cauliflower'],
#  ['meatballs', 'energy drink'],
#  ['meatballs', 'dessert wine'],
#  ['meatballs', 'chutney'],
#  ['meatballs', 'extra dark chocolate'],
#  ['meatballs', 'french wine'],
#  ['meatballs', 'pet food'],
#  ['meatballs', 'pepper'],
#  ['meatballs', 'french fries'],
#  ['meatballs', 'antioxydant juice'],
#  ['meatballs', 'spinach'],
#  ['meatballs', 'oatmeal'],
#  ['meatballs', 'sandwich'],
#  ['meatballs', 'mashed potato'],
#  ['meatballs', 'whole wheat rice'],
#  ['meatballs', 'energy bar'],
#  ['meatballs', 'hot dogs'],
#  ['meatballs', 'shallot'],
#  ['meatballs', 'tomato sauce'],
#  ['meatballs', 'frozen smoothie'],
#  ['meatballs', 'rice'],
#  ['meatballs', 'bramble'],
#  ['meatballs', 'pickles'],
#  ['meatballs', 'soda'],
#  ['meatballs', 'hand protein bar'],
#  ['meatballs', 'clothes accessories'],
#  ['meatballs', 'salad'],
#  ['meatballs', 'oil'],
#  ['meatballs', 'green grapes'],
#  ['meatballs', 'brownies'],
#  ['meatballs', 'soup'],
#  ['meatballs', 'eggplant'],
#  ['meatballs', 'cottage cheese'],
#  ['meatballs', 'whole wheat pasta'],
#  ['meatballs', 'napkins'],
#  ['meatballs', 'mushroom cream sauce'],
#  ['meatballs', 'mineral water'],
#  ['meatballs', 'turkey'],
#  ['meatballs', 'babies food'],
#  ['meatballs', 'flax seed'],
#  ['meatballs', 'salmon'],
#  ['meatballs', 'pancakes'],
#  ['meatballs', 'escalope'],
#  ['meatballs', 'honey'],
#  ['meatballs', 'cereals'],
#  ['meatballs', 'white wine'],
#  ['meatballs', 'tea'],
#  ['meatballs', 'vegetables mix'],
#  ['meatballs', 'milk'],
#  ['meatballs', 'mint green tea'],
#  ['meatballs', ' asparagus'],
#  ['meatballs', 'frozen vegetables'],
#  ['meatballs', 'olive oil'],
#  ['meatballs', 'zucchini'],
#  ['meatballs', 'carrots'],
#  ['meatballs', 'red wine'],
#  ['meatballs', 'nonfat milk'],
#  ['meatballs', 'ham'],
#  ['meatballs', 'blueberries'],
#  ['meatballs', 'gums'],
#  ['meatballs', 'chili'],
#  ['meatballs', 'pasta'],
#  ['meatballs', 'herb & pepper'],
#  ['meatballs', 'green beans'],
#  ['meatballs', 'cream'],
#  ['meatballs', 'fresh bread'],
#  ['meatballs', 'grated cheese'],
#  ['meatballs', 'avocado'],
#  ['meatballs', 'toothpaste'],
#  ['meatballs', 'whole weat flour'],
#  ['meatballs', 'eggs'],
#  ['meatballs', 'bug spray'],
#  ['meatballs', 'parmesan cheese'],
#  ['meatballs', 'yams'],
#  ['meatballs', 'almonds'],
#  ['meatballs', 'chicken'],
#  ['meatballs', 'butter'],
#  ['meatballs', 'water spray'],
#  ['meatballs', 'light cream'],
#  ['meatballs', 'light mayo'],
#  ['meatballs', 'chocolate bread'],
#  ['meatballs', 'cake'],
#  ['meatballs', 'protein bar'],
#  ['meatballs', 'black tea'],
#  ['meatballs', 'sparkling water'],
#  ['meatballs', 'burgers'],
#  ['low fat yogurt', 'magazines'],
#  ['low fat yogurt', 'shampoo'],
#  ['low fat yogurt', 'mint'],
#  ['low fat yogurt', 'candy bars'],
#  ['low fat yogurt', 'tomato juice'],
#  ['low fat yogurt', 'chocolate'],
#  ['low fat yogurt', 'corn'],
#  ['low fat yogurt', 'green tea'],
#  ['low fat yogurt', 'tomatoes'],
#  ['low fat yogurt', 'body spray'],
#  ['low fat yogurt', 'gluten free bar'],
#  ['low fat yogurt', 'champagne'],
#  ['low fat yogurt', 'burger sauce'],
#  ['low fat yogurt', 'strawberries'],
#  ['low fat yogurt', 'fromage blanc'],
#  ['low fat yogurt', 'salt'],
#  ['low fat yogurt', 'mayonnaise'],
#  ['low fat yogurt', 'cookies'],
#  ['low fat yogurt', 'cooking oil'],
#  ['low fat yogurt', 'barbecue sauce'],
#  ['low fat yogurt', 'bacon'],
#  ['low fat yogurt', 'shrimp'],
#  ['low fat yogurt', 'cider'],
#  ['low fat yogurt', 'yogurt cake'],
#  ['low fat yogurt', 'melons'],
#  ['low fat yogurt', 'ketchup'],
#  ['low fat yogurt', 'spaghetti'],
#  ['low fat yogurt', 'muffins'],
#  ['low fat yogurt', 'ground beef'],
#  ['low fat yogurt', 'asparagus'],
#  ['low fat yogurt', 'cauliflower'],
#  ['low fat yogurt', 'energy drink'],
#  ['low fat yogurt', 'dessert wine'],
#  ['low fat yogurt', 'chutney'],
#  ['low fat yogurt', 'extra dark chocolate'],
#  ['low fat yogurt', 'french wine'],
#  ['low fat yogurt', 'pet food'],
#  ['low fat yogurt', 'pepper'],
#  ['low fat yogurt', 'french fries'],
#  ['low fat yogurt', 'antioxydant juice'],
#  ['low fat yogurt', 'spinach'],
#  ['low fat yogurt', 'oatmeal'],
#  ['low fat yogurt', 'sandwich'],
#  ['low fat yogurt', 'mashed potato'],
#  ['low fat yogurt', 'whole wheat rice'],
#  ['low fat yogurt', 'energy bar'],
#  ['low fat yogurt', 'hot dogs'],
#  ['low fat yogurt', 'shallot'],
#  ['low fat yogurt', 'tomato sauce'],
#  ['low fat yogurt', 'frozen smoothie'],
#  ['low fat yogurt', 'rice'],
#  ['low fat yogurt', 'bramble'],
#  ['low fat yogurt', 'pickles'],
#  ['low fat yogurt', 'soda'],
#  ['low fat yogurt', 'hand protein bar'],
#  ['low fat yogurt', 'clothes accessories'],
#  ['low fat yogurt', 'salad'],
#  ['low fat yogurt', 'oil'],
#  ['low fat yogurt', 'green grapes'],
#  ['low fat yogurt', 'brownies'],
#  ['low fat yogurt', 'soup'],
#  ['low fat yogurt', 'eggplant'],
#  ['low fat yogurt', 'cottage cheese'],
#  ['low fat yogurt', 'whole wheat pasta'],
#  ['low fat yogurt', 'napkins'],
#  ['low fat yogurt', 'mushroom cream sauce'],
#  ['low fat yogurt', 'mineral water'],
#  ['low fat yogurt', 'turkey'],
#  ['low fat yogurt', 'babies food'],
#  ['low fat yogurt', 'flax seed'],
#  ['low fat yogurt', 'salmon'],
#  ['low fat yogurt', 'pancakes'],
#  ['low fat yogurt', 'escalope'],
#  ['low fat yogurt', 'honey'],
#  ['low fat yogurt', 'cereals'],
#  ['low fat yogurt', 'white wine'],
#  ['low fat yogurt', 'tea'],
#  ['low fat yogurt', 'vegetables mix'],
#  ['low fat yogurt', 'milk'],
#  ['low fat yogurt', 'mint green tea'],
#  ['low fat yogurt', ' asparagus'],
#  ['low fat yogurt', 'frozen vegetables'],
#  ['low fat yogurt', 'olive oil'],
#  ['low fat yogurt', 'zucchini'],
#  ['low fat yogurt', 'carrots'],
#  ['low fat yogurt', 'red wine'],
#  ['low fat yogurt', 'nonfat milk'],
#  ['low fat yogurt', 'ham'],
#  ['low fat yogurt', 'blueberries'],
#  ['low fat yogurt', 'gums'],
#  ['low fat yogurt', 'chili'],
#  ['low fat yogurt', 'pasta'],
#  ['low fat yogurt', 'herb & pepper'],
#  ['low fat yogurt', 'green beans'],
#  ['low fat yogurt', 'cream'],
#  ['low fat yogurt', 'fresh bread'],
#  ['low fat yogurt', 'grated cheese'],
#  ['low fat yogurt', 'avocado'],
#  ['low fat yogurt', 'toothpaste'],
#  ['low fat yogurt', 'whole weat flour'],
#  ['low fat yogurt', 'eggs'],
#  ['low fat yogurt', 'bug spray'],
#  ['low fat yogurt', 'parmesan cheese'],
#  ['low fat yogurt', 'yams'],
#  ['low fat yogurt', 'almonds'],
#  ['low fat yogurt', 'chicken'],
#  ['low fat yogurt', 'butter'],
#  ['low fat yogurt', 'water spray'],
#  ['low fat yogurt', 'light cream'],
#  ['low fat yogurt', 'light mayo'],
#  ['low fat yogurt', 'chocolate bread'],
#  ['low fat yogurt', 'cake'],
#  ['low fat yogurt', 'protein bar'],
#  ['low fat yogurt', 'black tea'],
#  ['low fat yogurt', 'sparkling water'],
#  ['low fat yogurt', 'burgers'],
#  ['magazines', 'shampoo'],
#  ['magazines', 'mint'],
#  ['magazines', 'candy bars'],
#  ['magazines', 'tomato juice'],
#  ['magazines', 'chocolate'],
#  ['magazines', 'corn'],
#  ['magazines', 'green tea'],
#  ['magazines', 'tomatoes'],
#  ['magazines', 'body spray'],
#  ['magazines', 'gluten free bar'],
#  ['magazines', 'champagne'],
#  ['magazines', 'burger sauce'],
#  ['magazines', 'strawberries'],
#  ['magazines', 'fromage blanc'],
#  ['magazines', 'salt'],
#  ['magazines', 'mayonnaise'],
#  ['magazines', 'cookies'],
#  ['magazines', 'cooking oil'],
#  ['magazines', 'barbecue sauce'],
#  ['magazines', 'bacon'],
#  ['magazines', 'shrimp'],
#  ['magazines', 'cider'],
#  ['magazines', 'yogurt cake'],
#  ['magazines', 'melons'],
#  ['magazines', 'ketchup'],
#  ['magazines', 'spaghetti'],
#  ['magazines', 'muffins'],
#  ['magazines', 'ground beef'],
#  ['magazines', 'asparagus'],
#  ['magazines', 'cauliflower'],
#  ['magazines', 'energy drink'],
#  ['magazines', 'dessert wine'],
#  ['magazines', 'chutney'],
#  ['magazines', 'extra dark chocolate'],
#  ['magazines', 'french wine'],
#  ['magazines', 'pet food'],
#  ['magazines', 'pepper'],
#  ['magazines', 'french fries'],
#  ['magazines', 'antioxydant juice'],
#  ['magazines', 'spinach'],
#  ['magazines', 'oatmeal'],
#  ['magazines', 'sandwich'],
#  ['magazines', 'mashed potato'],
#  ['magazines', 'whole wheat rice'],
#  ['magazines', 'energy bar'],
#  ['magazines', 'hot dogs'],
#  ['magazines', 'shallot'],
#  ['magazines', 'tomato sauce'],
#  ['magazines', 'frozen smoothie'],
#  ['magazines', 'rice'],
#  ['magazines', 'bramble'],
#  ['magazines', 'pickles'],
#  ['magazines', 'soda'],
#  ['magazines', 'hand protein bar'],
#  ['magazines', 'clothes accessories'],
#  ['magazines', 'salad'],
#  ['magazines', 'oil'],
#  ['magazines', 'green grapes'],
#  ['magazines', 'brownies'],
#  ['magazines', 'soup'],
#  ['magazines', 'eggplant'],
#  ['magazines', 'cottage cheese'],
#  ['magazines', 'whole wheat pasta'],
#  ['magazines', 'napkins'],
#  ['magazines', 'mushroom cream sauce'],
#  ['magazines', 'mineral water'],
#  ['magazines', 'turkey'],
#  ['magazines', 'babies food'],
#  ['magazines', 'flax seed'],
#  ['magazines', 'salmon'],
#  ['magazines', 'pancakes'],
#  ['magazines', 'escalope'],
#  ['magazines', 'honey'],
#  ['magazines', 'cereals'],
#  ['magazines', 'white wine'],
#  ['magazines', 'tea'],
#  ['magazines', 'vegetables mix'],
#  ['magazines', 'milk'],
#  ['magazines', 'mint green tea'],
#  ['magazines', ' asparagus'],
#  ['magazines', 'frozen vegetables'],
#  ['magazines', 'olive oil'],
#  ['magazines', 'zucchini'],
#  ['magazines', 'carrots'],
#  ['magazines', 'red wine'],
#  ['magazines', 'nonfat milk'],
#  ['magazines', 'ham'],
#  ['magazines', 'blueberries'],
#  ['magazines', 'gums'],
#  ['magazines', 'chili'],
#  ['magazines', 'pasta'],
#  ['magazines', 'herb & pepper'],
#  ['magazines', 'green beans'],
#  ['magazines', 'cream'],
#  ['magazines', 'fresh bread'],
#  ['magazines', 'grated cheese'],
#  ['magazines', 'avocado'],
#  ['magazines', 'toothpaste'],
#  ['magazines', 'whole weat flour'],
#  ['magazines', 'eggs'],
#  ['magazines', 'bug spray'],
#  ['magazines', 'parmesan cheese'],
#  ['magazines', 'yams'],
#  ['magazines', 'almonds'],
#  ['magazines', 'chicken'],
#  ['magazines', 'butter'],
#  ['magazines', 'water spray'],
#  ['magazines', 'light cream'],
#  ['magazines', 'light mayo'],
#  ['magazines', 'chocolate bread'],
#  ['magazines', 'cake'],
#  ['magazines', 'protein bar'],
#  ['magazines', 'black tea'],
#  ['magazines', 'sparkling water'],
#  ['magazines', 'burgers'],
#  ['shampoo', 'mint'],
#  ['shampoo', 'candy bars'],
#  ['shampoo', 'tomato juice'],
#  ['shampoo', 'chocolate'],
#  ['shampoo', 'corn'],
#  ['shampoo', 'green tea'],
#  ['shampoo', 'tomatoes'],
#  ['shampoo', 'body spray'],
#  ['shampoo', 'gluten free bar'],
#  ['shampoo', 'champagne'],
#  ['shampoo', 'burger sauce'],
#  ['shampoo', 'strawberries'],
#  ['shampoo', 'fromage blanc'],
#  ['shampoo', 'salt'],
#  ['shampoo', 'mayonnaise'],
#  ['shampoo', 'cookies'],
#  ['shampoo', 'cooking oil'],
#  ['shampoo', 'barbecue sauce'],
#  ['shampoo', 'bacon'],
#  ['shampoo', 'shrimp'],
#  ['shampoo', 'cider'],
#  ['shampoo', 'yogurt cake'],
#  ['shampoo', 'melons'],
#  ['shampoo', 'ketchup'],
#  ['shampoo', 'spaghetti'],
#  ['shampoo', 'muffins'],
#  ['shampoo', 'ground beef'],
#  ['shampoo', 'asparagus'],
#  ['shampoo', 'cauliflower'],
#  ['shampoo', 'energy drink'],
#  ['shampoo', 'dessert wine'],
#  ['shampoo', 'chutney'],
#  ['shampoo', 'extra dark chocolate'],
#  ['shampoo', 'french wine'],
#  ['shampoo', 'pet food'],
#  ['shampoo', 'pepper'],
#  ['shampoo', 'french fries'],
#  ['shampoo', 'antioxydant juice'],
#  ['shampoo', 'spinach'],
#  ['shampoo', 'oatmeal'],
#  ['shampoo', 'sandwich'],
#  ['shampoo', 'mashed potato'],
#  ['shampoo', 'whole wheat rice'],
#  ['shampoo', 'energy bar'],
#  ['shampoo', 'hot dogs'],
#  ['shampoo', 'shallot'],
#  ['shampoo', 'tomato sauce'],
#  ['shampoo', 'frozen smoothie'],
#  ['shampoo', 'rice'],
#  ['shampoo', 'bramble'],
#  ['shampoo', 'pickles'],
#  ['shampoo', 'soda'],
#  ['shampoo', 'hand protein bar'],
#  ['shampoo', 'clothes accessories'],
#  ['shampoo', 'salad'],
#  ['shampoo', 'oil'],
#  ['shampoo', 'green grapes'],
#  ['shampoo', 'brownies'],
#  ['shampoo', 'soup'],
#  ['shampoo', 'eggplant'],
#  ['shampoo', 'cottage cheese'],
#  ['shampoo', 'whole wheat pasta'],
#  ['shampoo', 'napkins'],
#  ['shampoo', 'mushroom cream sauce'],
#  ['shampoo', 'mineral water'],
#  ['shampoo', 'turkey'],
#  ['shampoo', 'babies food'],
#  ['shampoo', 'flax seed'],
#  ['shampoo', 'salmon'],
#  ['shampoo', 'pancakes'],
#  ['shampoo', 'escalope'],
#  ['shampoo', 'honey'],
#  ['shampoo', 'cereals'],
#  ['shampoo', 'white wine'],
#  ['shampoo', 'tea'],
#  ['shampoo', 'vegetables mix'],
#  ['shampoo', 'milk'],
#  ['shampoo', 'mint green tea'],
#  ['shampoo', ' asparagus'],
#  ['shampoo', 'frozen vegetables'],
#  ['shampoo', 'olive oil'],
#  ['shampoo', 'zucchini'],
#  ['shampoo', 'carrots'],
#  ['shampoo', 'red wine'],
#  ['shampoo', 'nonfat milk'],
#  ['shampoo', 'ham'],
#  ['shampoo', 'blueberries'],
#  ['shampoo', 'gums'],
#  ['shampoo', 'chili'],
#  ['shampoo', 'pasta'],
#  ['shampoo', 'herb & pepper'],
#  ['shampoo', 'green beans'],
#  ['shampoo', 'cream'],
#  ['shampoo', 'fresh bread'],
#  ['shampoo', 'grated cheese'],
#  ['shampoo', 'avocado'],
#  ['shampoo', 'toothpaste'],
#  ['shampoo', 'whole weat flour'],
#  ['shampoo', 'eggs'],
#  ['shampoo', 'bug spray'],
#  ['shampoo', 'parmesan cheese'],
#  ['shampoo', 'yams'],
#  ['shampoo', 'almonds'],
#  ['shampoo', 'chicken'],
#  ['shampoo', 'butter'],
#  ['shampoo', 'water spray'],
#  ['shampoo', 'light cream'],
#  ['shampoo', 'light mayo'],
#  ['shampoo', 'chocolate bread'],
#  ['shampoo', 'cake'],
#  ['shampoo', 'protein bar'],
#  ['shampoo', 'black tea'],
#  ['shampoo', 'sparkling water'],
#  ['shampoo', 'burgers'],
#  ['mint', 'candy bars'],
#  ['mint', 'tomato juice'],
#  ['mint', 'chocolate'],
#  ['mint', 'corn'],
#  ['mint', 'green tea'],
#  ['mint', 'tomatoes'],
#  ['mint', 'body spray'],
#  ['mint', 'gluten free bar'],
#  ['mint', 'champagne'],
#  ['mint', 'burger sauce'],
#  ['mint', 'strawberries'],
#  ['mint', 'fromage blanc'],
#  ['mint', 'salt'],
#  ['mint', 'mayonnaise'],
#  ['mint', 'cookies'],
#  ['mint', 'cooking oil'],
#  ['mint', 'barbecue sauce'],
#  ['mint', 'bacon'],
#  ['mint', 'shrimp'],
#  ['mint', 'cider'],
#  ['mint', 'yogurt cake'],
#  ['mint', 'melons'],
#  ['mint', 'ketchup'],
#  ['mint', 'spaghetti'],
#  ['mint', 'muffins'],
#  ['mint', 'ground beef'],
#  ['mint', 'asparagus'],
#  ['mint', 'cauliflower'],
#  ['mint', 'energy drink'],
#  ['mint', 'dessert wine'],
#  ['mint', 'chutney'],
#  ['mint', 'extra dark chocolate'],
#  ['mint', 'french wine'],
#  ['mint', 'pet food'],
#  ['mint', 'pepper'],
#  ['mint', 'french fries'],
#  ['mint', 'antioxydant juice'],
#  ['mint', 'spinach'],
#  ['mint', 'oatmeal'],
#  ['mint', 'sandwich'],
#  ['mint', 'mashed potato'],
#  ['mint', 'whole wheat rice'],
#  ['mint', 'energy bar'],
#  ['mint', 'hot dogs'],
#  ['mint', 'shallot'],
#  ['mint', 'tomato sauce'],
#  ['mint', 'frozen smoothie'],
#  ['mint', 'rice'],
#  ['mint', 'bramble'],
#  ['mint', 'pickles'],
#  ['mint', 'soda'],
#  ['mint', 'hand protein bar'],
#  ['mint', 'clothes accessories'],
#  ['mint', 'salad'],
#  ['mint', 'oil'],
#  ['mint', 'green grapes'],
#  ['mint', 'brownies'],
#  ['mint', 'soup'],
#  ['mint', 'eggplant'],
#  ['mint', 'cottage cheese'],
#  ['mint', 'whole wheat pasta'],
#  ['mint', 'napkins'],
#  ['mint', 'mushroom cream sauce'],
#  ['mint', 'mineral water'],
#  ['mint', 'turkey'],
#  ['mint', 'babies food'],
#  ['mint', 'flax seed'],
#  ['mint', 'salmon'],
#  ['mint', 'pancakes'],
#  ['mint', 'escalope'],
#  ['mint', 'honey'],
#  ['mint', 'cereals'],
#  ['mint', 'white wine'],
#  ['mint', 'tea'],
#  ['mint', 'vegetables mix'],
#  ['mint', 'milk'],
#  ['mint', 'mint green tea'],
#  ['mint', ' asparagus'],
#  ['mint', 'frozen vegetables'],
#  ['mint', 'olive oil'],
#  ['mint', 'zucchini'],
#  ['mint', 'carrots'],
#  ['mint', 'red wine'],
#  ['mint', 'nonfat milk'],
#  ['mint', 'ham'],
#  ['mint', 'blueberries'],
#  ['mint', 'gums'],
#  ['mint', 'chili'],
#  ['mint', 'pasta'],
#  ['mint', 'herb & pepper'],
#  ['mint', 'green beans'],
#  ['mint', 'cream'],
#  ['mint', 'fresh bread'],
#  ['mint', 'grated cheese'],
#  ['mint', 'avocado'],
#  ['mint', 'toothpaste'],
#  ['mint', 'whole weat flour'],
#  ['mint', 'eggs'],
#  ['mint', 'bug spray'],
#  ['mint', 'parmesan cheese'],
#  ['mint', 'yams'],
#  ['mint', 'almonds'],
#  ['mint', 'chicken'],
#  ['mint', 'butter'],
#  ['mint', 'water spray'],
#  ['mint', 'light cream'],
#  ['mint', 'light mayo'],
#  ['mint', 'chocolate bread'],
#  ['mint', 'cake'],
#  ['mint', 'protein bar'],
#  ['mint', 'black tea'],
#  ['mint', 'sparkling water'],
#  ['mint', 'burgers'],
#  ['candy bars', 'tomato juice'],
#  ['candy bars', 'chocolate'],
#  ['candy bars', 'corn'],
#  ['candy bars', 'green tea'],
#  ['candy bars', 'tomatoes'],
#  ['candy bars', 'body spray'],
#  ['candy bars', 'gluten free bar'],
#  ['candy bars', 'champagne'],
#  ['candy bars', 'burger sauce'],
#  ['candy bars', 'strawberries'],
#  ['candy bars', 'fromage blanc'],
#  ['candy bars', 'salt'],
#  ['candy bars', 'mayonnaise'],
#  ['candy bars', 'cookies'],
#  ['candy bars', 'cooking oil'],
#  ['candy bars', 'barbecue sauce'],
#  ['candy bars', 'bacon'],
#  ['candy bars', 'shrimp'],
#  ['candy bars', 'cider'],
#  ['candy bars', 'yogurt cake'],
#  ['candy bars', 'melons'],
#  ['candy bars', 'ketchup'],
#  ['candy bars', 'spaghetti'],
#  ['candy bars', 'muffins'],
#  ['candy bars', 'ground beef'],
#  ['candy bars', 'asparagus'],
#  ['candy bars', 'cauliflower'],
#  ['candy bars', 'energy drink'],
#  ['candy bars', 'dessert wine'],
#  ['candy bars', 'chutney'],
#  ['candy bars', 'extra dark chocolate'],
#  ['candy bars', 'french wine'],
#  ['candy bars', 'pet food'],
#  ['candy bars', 'pepper'],
#  ['candy bars', 'french fries'],
#  ['candy bars', 'antioxydant juice'],
#  ['candy bars', 'spinach'],
#  ['candy bars', 'oatmeal'],
#  ['candy bars', 'sandwich'],
#  ['candy bars', 'mashed potato'],
#  ['candy bars', 'whole wheat rice'],
#  ['candy bars', 'energy bar'],
#  ['candy bars', 'hot dogs'],
#  ['candy bars', 'shallot'],
#  ['candy bars', 'tomato sauce'],
#  ['candy bars', 'frozen smoothie'],
#  ['candy bars', 'rice'],
#  ['candy bars', 'bramble'],
#  ['candy bars', 'pickles'],
#  ['candy bars', 'soda'],
#  ['candy bars', 'hand protein bar'],
#  ['candy bars', 'clothes accessories'],
#  ['candy bars', 'salad'],
#  ['candy bars', 'oil'],
#  ['candy bars', 'green grapes'],
#  ['candy bars', 'brownies'],
#  ['candy bars', 'soup'],
#  ['candy bars', 'eggplant'],
#  ['candy bars', 'cottage cheese'],
#  ['candy bars', 'whole wheat pasta'],
#  ['candy bars', 'napkins'],
#  ['candy bars', 'mushroom cream sauce'],
#  ['candy bars', 'mineral water'],
#  ['candy bars', 'turkey'],
#  ['candy bars', 'babies food'],
#  ['candy bars', 'flax seed'],
#  ['candy bars', 'salmon'],
#  ['candy bars', 'pancakes'],
#  ['candy bars', 'escalope'],
#  ['candy bars', 'honey'],
#  ['candy bars', 'cereals'],
#  ['candy bars', 'white wine'],
#  ['candy bars', 'tea'],
#  ['candy bars', 'vegetables mix'],
#  ['candy bars', 'milk'],
#  ['candy bars', 'mint green tea'],
#  ['candy bars', ' asparagus'],
#  ['candy bars', 'frozen vegetables'],
#  ['candy bars', 'olive oil'],
#  ['candy bars', 'zucchini'],
#  ['candy bars', 'carrots'],
#  ['candy bars', 'red wine'],
#  ['candy bars', 'nonfat milk'],
#  ['candy bars', 'ham'],
#  ['candy bars', 'blueberries'],
#  ['candy bars', 'gums'],
#  ['candy bars', 'chili'],
#  ['candy bars', 'pasta'],
#  ['candy bars', 'herb & pepper'],
#  ['candy bars', 'green beans'],
#  ['candy bars', 'cream'],
#  ['candy bars', 'fresh bread'],
#  ['candy bars', 'grated cheese'],
#  ['candy bars', 'avocado'],
#  ['candy bars', 'toothpaste'],
#  ['candy bars', 'whole weat flour'],
#  ['candy bars', 'eggs'],
#  ['candy bars', 'bug spray'],
#  ['candy bars', 'parmesan cheese'],
#  ['candy bars', 'yams'],
#  ['candy bars', 'almonds'],
#  ['candy bars', 'chicken'],
#  ['candy bars', 'butter'],
#  ['candy bars', 'water spray'],
#  ['candy bars', 'light cream'],
#  ['candy bars', 'light mayo'],
#  ['candy bars', 'chocolate bread'],
#  ['candy bars', 'cake'],
#  ['candy bars', 'protein bar'],
#  ['candy bars', 'black tea'],
#  ['candy bars', 'sparkling water'],
#  ['candy bars', 'burgers'],
#  ['tomato juice', 'chocolate'],
#  ['tomato juice', 'corn'],
#  ['tomato juice', 'green tea'],
#  ['tomato juice', 'tomatoes'],
#  ['tomato juice', 'body spray'],
#  ['tomato juice', 'gluten free bar'],
#  ['tomato juice', 'champagne'],
#  ['tomato juice', 'burger sauce'],
#  ['tomato juice', 'strawberries'],
#  ['tomato juice', 'fromage blanc'],
#  ['tomato juice', 'salt'],
#  ['tomato juice', 'mayonnaise'],
#  ['tomato juice', 'cookies'],
#  ['tomato juice', 'cooking oil'],
#  ['tomato juice', 'barbecue sauce'],
#  ['tomato juice', 'bacon'],
#  ['tomato juice', 'shrimp'],
#  ['tomato juice', 'cider'],
#  ['tomato juice', 'yogurt cake'],
#  ['tomato juice', 'melons'],
#  ['tomato juice', 'ketchup'],
#  ['tomato juice', 'spaghetti'],
#  ['tomato juice', 'muffins'],
#  ['tomato juice', 'ground beef'],
#  ['tomato juice', 'asparagus'],
#  ['tomato juice', 'cauliflower'],
#  ['tomato juice', 'energy drink'],
#  ['tomato juice', 'dessert wine'],
#  ['tomato juice', 'chutney'],
#  ['tomato juice', 'extra dark chocolate'],
#  ['tomato juice', 'french wine'],
#  ['tomato juice', 'pet food'],
#  ['tomato juice', 'pepper'],
#  ['tomato juice', 'french fries'],
#  ['tomato juice', 'antioxydant juice'],
#  ['tomato juice', 'spinach'],
#  ['tomato juice', 'oatmeal'],
#  ['tomato juice', 'sandwich'],
#  ['tomato juice', 'mashed potato'],
#  ['tomato juice', 'whole wheat rice'],
#  ['tomato juice', 'energy bar'],
#  ['tomato juice', 'hot dogs'],
#  ['tomato juice', 'shallot'],
#  ['tomato juice', 'tomato sauce'],
#  ['tomato juice', 'frozen smoothie'],
#  ['tomato juice', 'rice'],
#  ['tomato juice', 'bramble'],
#  ['tomato juice', 'pickles'],
#  ['tomato juice', 'soda'],
#  ['tomato juice', 'hand protein bar'],
#  ['tomato juice', 'clothes accessories'],
#  ['tomato juice', 'salad'],
#  ['tomato juice', 'oil'],
#  ['tomato juice', 'green grapes'],
#  ['tomato juice', 'brownies'],
#  ['tomato juice', 'soup'],
#  ['tomato juice', 'eggplant'],
#  ['tomato juice', 'cottage cheese'],
#  ['tomato juice', 'whole wheat pasta'],
#  ['tomato juice', 'napkins'],
#  ['tomato juice', 'mushroom cream sauce'],
#  ['tomato juice', 'mineral water'],
#  ['tomato juice', 'turkey'],
#  ['tomato juice', 'babies food'],
#  ['tomato juice', 'flax seed'],
#  ['tomato juice', 'salmon'],
#  ['tomato juice', 'pancakes'],
#  ['tomato juice', 'escalope'],
#  ['tomato juice', 'honey'],
#  ['tomato juice', 'cereals'],
#  ['tomato juice', 'white wine'],
#  ['tomato juice', 'tea'],
#  ['tomato juice', 'vegetables mix'],
#  ['tomato juice', 'milk'],
#  ['tomato juice', 'mint green tea'],
#  ['tomato juice', ' asparagus'],
#  ...]

# %% [markdown]
# #### Calculating score
# The calculation is done looking at the number of customers that bought both items (the pair) and divided by all customers of the week (7501). This calculation is done for all pairs possible and the score is returned on "score" list.
#
# $ score = \frac{\text{number of lists that contain [item x and item y]}} {\text{number of all lists}} $

# %%
# %%time
score = []
for i in pair:
    cond = []
    for item in i:
        cond.append('("%s") in s' %item)
    mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
    #mycode = "print 'hello world'"
    score.append(len(eval(mycode))/7501.)
# Out:
# CPU times: user 21.7 s, sys: 4.03 ms, total: 21.7 s
# Wall time: 21.7 s

# %% [markdown]
# #### Showing results
#
# Top 10 Most common pairs of items of this week

# %%
ranking_ECLAT = pd.DataFrame([pair, score]).transpose()
ranking_ECLAT.columns = ['Pair', 'Score']

# %%
ranking_ECLAT.sort_values('Score', ascending=False).head(10)
# Out:
#                                     Pair      Score
# 3174          [spaghetti, mineral water]  0.0597254
# 1095          [chocolate, mineral water]  0.0526596
# 5948               [mineral water, eggs]  0.0509265
# 5926               [mineral water, milk]  0.0479936
# 3349        [ground beef, mineral water]  0.0409279
# 3136            [spaghetti, ground beef]  0.0391948
# 1055              [chocolate, spaghetti]  0.0391948
# 3208                   [spaghetti, eggs]  0.0365285
# 4198                [french fries, eggs]  0.0363951
# 5929  [mineral water, frozen vegetables]  0.0357286

# %% [markdown]
# ### What if we do that for trios?

# %%
# Creating trios
trio = []
for j in range(0, len(uniqueItems)):
    for k in range(j, len(uniqueItems)):
        for l in range(k, len(uniqueItems)):
            if (k != j) and (j != l) and (k != l):
                try:
                    trio.append([uniqueItems[j], uniqueItems[j+k], uniqueItems[j+l]])
                except IndexError:
                    pass

# %%
trio[:5]
# Out:
# [['fresh tuna', 'strong cheese', 'meatballs'],
#  ['fresh tuna', 'strong cheese', 'low fat yogurt'],
#  ['fresh tuna', 'strong cheese', 'magazines'],
#  ['fresh tuna', 'strong cheese', 'shampoo'],
#  ['fresh tuna', 'strong cheese', 'mint']]

# %%
# %%time
score_trio = []
for i in trio:
    cond = []
    for item in i:
        cond.append('("%s") in s' %item)
    mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
    #mycode = "print 'hello world'"
    score_trio.append(len(eval(mycode))/7501.)
# Out:
# CPU times: user 6min 13s, sys: 116 ms, total: 6min 13s
# Wall time: 6min 13s

# %%
ranking_ECLAT_trio = pd.DataFrame([trio, score_trio]).transpose()
ranking_ECLAT_trio.columns = ['Trio', 'Score']
ranking_ECLAT_trio.sort_values('Score', ascending=False).head(10)
# Out:
#                                                  Trio      Score
# 56149           [chocolate, spaghetti, mineral water]  0.0158646
# 125142               [spaghetti, mineral water, milk]  0.0157312
# 125164               [spaghetti, mineral water, eggs]  0.0142648
# 58901                [chocolate, mineral water, milk]  0.0139981
# 58923                [chocolate, mineral water, eggs]  0.0134649
# 125145  [spaghetti, mineral water, frozen vegetables]  0.0119984
# 125135           [spaghetti, mineral water, pancakes]  0.0114651
# 128223             [ground beef, mineral water, milk]  0.0110652
# 56324         [chocolate, ground beef, mineral water]  0.0109319
# 56161                    [chocolate, spaghetti, milk]  0.0109319

# %% [markdown]
# ## What about comparing the results from Apriori and ECLAT?

# %% [markdown]
# We got from Apriori that the combination that lead to more "attractiveness power" is "olive oil", "whole wheat pasta" and "mineral water". If we run the ECLAT code for this set of items, we will obtain: 0.0039.
#
# This score of 3 items has not enough score to be placed among top 10, but they are measuring different metrics.  According to apriori these are the items that when picked one lead to another items more frequently than other combinations, i.e. when a person pick 'olive oil', the probability of picking 'whole wheat pasta' and 'mineral water' is much higher than picking another combination. ECLAT in another hand is just sorting as the most common combinations of all lists, not caring about how one item isolatedly can influence in the purchase of another.

# %%
i = ["olive oil", "whole wheat pasta", "mineral water"]
cond = []
for item in i:
    cond.append('("{}") in s'.format(item))
mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
tra = eval(mycode)

# %%
cond
# Out:
# ['("olive oil") in s', '("whole wheat pasta") in s', '("mineral water") in s']

# %%
mycode
# Out:
# '[s for s in transactions if ("olive oil") in s and ("whole wheat pasta") in s and ("mineral water") in s]'

# %%
tra
# Out:
# [['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'almonds',
#   'french wine',
#   'yogurt cake',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cooking oil',
#   'frozen smoothie',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'fresh tuna',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'olive oil',
#   'almonds',
#   'cake',
#   'chicken',
#   'extra dark chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'carrots',
#   'protein bar',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'milk',
#   'olive oil',
#   'muffins',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'chicken',
#   'salmon',
#   'pancakes',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'cooking oil',
#   'ketchup',
#   'champagne',
#   'cookies',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'chicken',
#   'gums',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'avocado',
#   'olive oil',
#   'frozen smoothie',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'herb & pepper',
#   'tomatoes',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'vegetables mix',
#   'pancakes',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'salmon',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'hot dogs',
#   'cottage cheese',
#   'energy drink',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'turkey',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'eggs',
#   'cake',
#   'cooking oil',
#   'cereals',
#   'french fries',
#   'mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'olive oil',
#   'chicken',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'energy bar',
#   'frozen smoothie',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'ham',
#   'whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'honey',
#   'frozen smoothie',
#   'cottage cheese',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'tomatoes',
#   'whole wheat pasta',
#   'mineral water',
#   'chocolate',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'bacon',
#   'cake',
#   'gums',
#   'pancakes',
#   'yogurt cake',
#   'tomato juice',
#   'magazines',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'french wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cake',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'energy bar',
#   'chicken',
#   'white wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'escalope',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'black tea',
#   'salmon',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'salmon',
#   'cooking oil',
#   'low fat yogurt',
#   'zucchini',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
print ('Score for "olive oil", "whole wheat pasta", "mineral water": {}'.format(len(tra)/7501.))
# Out:
# Score for "olive oil", "whole wheat pasta", "mineral water": 0.0038661511798426876
