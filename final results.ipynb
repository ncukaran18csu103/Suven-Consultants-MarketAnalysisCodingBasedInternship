# %%
#importing libraries
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
# Data Loading
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# %%
#Adding all transactions into list of lists..
groceries=[]
for i in range(0,7500):
    groceries.append([str(dataset.values[i,j]) for j in range(0,10)])

# %%
#Eclat Implementation
#getting the products bought by customers...

groceriess=[]
for i in range(0,len(groceries)):
    groceriess.extend(groceries[i])
    
#Finding Unique items from differennt transactions and removing Nan
uniqueItems=list(set(groceriess))
uniqueItems.remove('nan')

# %%
print(groceriess)
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'burgers', 'meatballs', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'chutney', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'turkey', 'avocado', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea', 'nan', 'nan', 'nan', 'nan', 'nan', 'low fat yogurt', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'whole wheat pasta', 'french fries', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'soup', 'light cream', 'shallot', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'frozen vegetables', 'spaghetti', 'green tea', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'french fries', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'eggs', 'pet food', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'cookies', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil', 'nan', 'nan', 'nan', 'nan', 'nan', 'spaghetti', 'champagne', 'cookies', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'mineral water', 'salmon', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'mineral water', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt', 'nan', 'nan', 'nan', 'turkey', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra dark chocolate', 'meatballs', 'milk', 'honey', 'french fries', 'protein bar', 'nan', 'nan', 'nan', 'nan', 'nan', 'red wine', 'shrimp', 'pasta', 'pepper', 'eggs', 'chocolate', 'shampoo', 'nan', 'nan', 'nan', 'rice', 'sparkling water', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'spaghetti', 'mineral water', 'ham', 'body spray', 'pancakes', 'green tea', 'nan', 'nan', 'nan', 'nan', 'burgers', 'grated cheese', 'shrimp', 'pasta', 'avocado', 'honey', 'white wine', 'toothpaste', 'nan', 'nan', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'parmesan cheese', 'spaghetti', 'soup', 'avocado', 'milk', 'fresh bread', 'nan', 'nan', 'nan', 'nan', 'ground beef', 'spaghetti', 'mineral water', 'milk', 'energy bar', 'black tea', 'salmon', 'frozen smoothie', 'escalope', 'nan', 'sparkling water', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'mineral water', 'eggs', 'chicken', 'chocolate', 'french fries', 'nan', 'nan', 'nan', 'nan', 'nan', 'frozen vegetables', 'spaghetti', 'yams', 'mineral water', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'herb & pepper', 'tomato sauce', 'light cream', 'magazines', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'mineral water', 'chocolate', 'avocado', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'turkey', 'french fries', 'strawberries', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'frozen vegetables', 'strong cheese', 'chocolate', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'cookies', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'pickles', 'spaghetti', 'salmon', 'escalope', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'energy bar', 'french fries', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'red wine', 'ground beef', 'mineral water', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'mineral water', 'cake', 'cottage cheese', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'pickles', 'champagne', 'green tea', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'spaghetti', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'fresh tuna', 'frozen vegetables', 'spaghetti', 'mineral water', 'honey', 'whole wheat rice', 'frozen smoothie', 'escalope', 'nan', 'nan', 'spaghetti', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'soup', 'meatb ...

# %%
print(uniqueItems)
# Out:
# ['blueberries', 'burgers', 'sparkling water', 'burger sauce', 'brownies', 'light cream', 'carrots', 'antioxydant juice', 'vegetables mix', 'sandwich', 'gluten free bar', 'rice', 'whole wheat rice', 'mint green tea', 'pepper', 'parmesan cheese', 'corn', 'mashed potato', 'cookies', 'energy bar', 'spaghetti', 'ground beef', 'eggs', 'cream', 'whole weat flour', 'almonds', 'red wine', 'yams', 'grated cheese', 'french fries', 'honey', 'salt', 'avocado', 'tomato juice', 'babies food', 'barbecue sauce', 'tomatoes', 'milk', 'strong cheese', 'shampoo', 'bug spray', 'salad', 'candy bars', 'muffins', 'green grapes', 'mint', 'fresh bread', 'gums', 'shallot', 'white wine', 'green tea', 'champagne', 'ham', 'escalope', 'fresh tuna', 'chocolate', 'mineral water', 'black tea', 'frozen smoothie', 'shrimp', 'soup', 'body spray', 'chili', 'melons', 'mayonnaise', 'clothes accessories', 'soda', 'pasta', 'flax seed', 'bramble', 'yogurt cake', 'oatmeal', 'cake', 'low fat yogurt', 'mushroom cream sauce', ' asparagus', 'cottage cheese', 'light mayo', 'spinach', 'cereals', 'water spray', 'napkins', 'french wine', 'asparagus', 'pet food', 'salmon', 'tomato sauce', 'pickles', 'eggplant', 'zucchini', 'pancakes', 'green beans', 'ketchup', 'fromage blanc', 'strawberries', 'dessert wine', 'cider', 'frozen vegetables', 'nonfat milk', 'meatballs', 'butter', 'bacon', 'turkey', 'magazines', 'oil', 'olive oil', 'cauliflower', 'herb & pepper', 'hand protein bar', 'whole wheat pasta', 'chocolate bread', 'toothpaste', 'protein bar', 'tea', 'chutney', 'extra dark chocolate', 'hot dogs', 'cooking oil', 'chicken', 'energy drink']

# %%
# Creating Combinations with items-pairs....
pairs=[]
for j in range(0,len(uniqueItems)):
    k=1;
    while(k<len(uniqueItems)):
        try:
            pairs.append([uniqueItems[j],uniqueItems[j+k]])
        except IndexError:
            pass
        k=k+1;

# %%
print(pairs[:10])
print(pairs[:-10])
# Out:
# [['blueberries', 'burgers'], ['blueberries', 'sparkling water'], ['blueberries', 'burger sauce'], ['blueberries', 'brownies'], ['blueberries', 'light cream'], ['blueberries', 'carrots'], ['blueberries', 'antioxydant juice'], ['blueberries', 'vegetables mix'], ['blueberries', 'sandwich'], ['blueberries', 'gluten free bar']]
# [['blueberries', 'burgers'], ['blueberries', 'sparkling water'], ['blueberries', 'burger sauce'], ['blueberries', 'brownies'], ['blueberries', 'light cream'], ['blueberries', 'carrots'], ['blueberries', 'antioxydant juice'], ['blueberries', 'vegetables mix'], ['blueberries', 'sandwich'], ['blueberries', 'gluten free bar'], ['blueberries', 'rice'], ['blueberries', 'whole wheat rice'], ['blueberries', 'mint green tea'], ['blueberries', 'pepper'], ['blueberries', 'parmesan cheese'], ['blueberries', 'corn'], ['blueberries', 'mashed potato'], ['blueberries', 'cookies'], ['blueberries', 'energy bar'], ['blueberries', 'spaghetti'], ['blueberries', 'ground beef'], ['blueberries', 'eggs'], ['blueberries', 'cream'], ['blueberries', 'whole weat flour'], ['blueberries', 'almonds'], ['blueberries', 'red wine'], ['blueberries', 'yams'], ['blueberries', 'grated cheese'], ['blueberries', 'french fries'], ['blueberries', 'honey'], ['blueberries', 'salt'], ['blueberries', 'avocado'], ['blueberries', 'tomato juice'], ['blueberries', 'babies food'], ['blueberries', 'barbecue sauce'], ['blueberries', 'tomatoes'], ['blueberries', 'milk'], ['blueberries', 'strong cheese'], ['blueberries', 'shampoo'], ['blueberries', 'bug spray'], ['blueberries', 'salad'], ['blueberries', 'candy bars'], ['blueberries', 'muffins'], ['blueberries', 'green grapes'], ['blueberries', 'mint'], ['blueberries', 'fresh bread'], ['blueberries', 'gums'], ['blueberries', 'shallot'], ['blueberries', 'white wine'], ['blueberries', 'green tea'], ['blueberries', 'champagne'], ['blueberries', 'ham'], ['blueberries', 'escalope'], ['blueberries', 'fresh tuna'], ['blueberries', 'chocolate'], ['blueberries', 'mineral water'], ['blueberries', 'black tea'], ['blueberries', 'frozen smoothie'], ['blueberries', 'shrimp'], ['blueberries', 'soup'], ['blueberries', 'body spray'], ['blueberries', 'chili'], ['blueberries', 'melons'], ['blueberries', 'mayonnaise'], ['blueberries', 'clothes accessories'], ['blueberries', 'soda'], ['blueberries', 'pasta'], ['blueberries', 'flax seed'], ['blueberries', 'bramble'], ['blueberries', 'yogurt cake'], ['blueberries', 'oatmeal'], ['blueberries', 'cake'], ['blueberries', 'low fat yogurt'], ['blueberries', 'mushroom cream sauce'], ['blueberries', ' asparagus'], ['blueberries', 'cottage cheese'], ['blueberries', 'light mayo'], ['blueberries', 'spinach'], ['blueberries', 'cereals'], ['blueberries', 'water spray'], ['blueberries', 'napkins'], ['blueberries', 'french wine'], ['blueberries', 'asparagus'], ['blueberries', 'pet food'], ['blueberries', 'salmon'], ['blueberries', 'tomato sauce'], ['blueberries', 'pickles'], ['blueberries', 'eggplant'], ['blueberries', 'zucchini'], ['blueberries', 'pancakes'], ['blueberries', 'green beans'], ['blueberries', 'ketchup'], ['blueberries', 'fromage blanc'], ['blueberries', 'strawberries'], ['blueberries', 'dessert wine'], ['blueberries', 'cider'], ['blueberries', 'frozen vegetables'], ['blueberries', 'nonfat milk'], ['blueberries', 'meatballs'], ['blueberries', 'butter'], ['blueberries', 'bacon'], ['blueberries', 'turkey'], ['blueberries', 'magazines'], ['blueberries', 'oil'], ['blueberries', 'olive oil'], ['blueberries', 'cauliflower'], ['blueberries', 'herb & pepper'], ['blueberries', 'hand protein bar'], ['blueberries', 'whole wheat pasta'], ['blueberries', 'chocolate bread'], ['blueberries', 'toothpaste'], ['blueberries', 'protein bar'], ['blueberries', 'tea'], ['blueberries', 'chutney'], ['blueberries', 'extra dark chocolate'], ['blueberries', 'hot dogs'], ['blueberries', 'cooking oil'], ['blueberries', 'chicken'], ['blueberries', 'energy drink'], ['burgers', 'sparkling water'], ['burgers', 'burger sauce'], ['burgers', 'brownies'], ['burgers', 'light cream'], ['burgers', 'carrots'], ['burgers', 'antioxydant juice'], ['burgers', 'vegetables mix'], ['burgers', 'sandwich'], ['burgers', 'gluten free bar'], ['burgers', 'rice'], ['burgers', 'whole wheat rice'], ['burgers', 'mint green tea'], ['burgers', 'pepper'], ['burgers', ...

# %%
pairs
# Out:
# [['blueberries', 'burgers'],
#  ['blueberries', 'sparkling water'],
#  ['blueberries', 'burger sauce'],
#  ['blueberries', 'brownies'],
#  ['blueberries', 'light cream'],
#  ['blueberries', 'carrots'],
#  ['blueberries', 'antioxydant juice'],
#  ['blueberries', 'vegetables mix'],
#  ['blueberries', 'sandwich'],
#  ['blueberries', 'gluten free bar'],
#  ['blueberries', 'rice'],
#  ['blueberries', 'whole wheat rice'],
#  ['blueberries', 'mint green tea'],
#  ['blueberries', 'pepper'],
#  ['blueberries', 'parmesan cheese'],
#  ['blueberries', 'corn'],
#  ['blueberries', 'mashed potato'],
#  ['blueberries', 'cookies'],
#  ['blueberries', 'energy bar'],
#  ['blueberries', 'spaghetti'],
#  ['blueberries', 'ground beef'],
#  ['blueberries', 'eggs'],
#  ['blueberries', 'cream'],
#  ['blueberries', 'whole weat flour'],
#  ['blueberries', 'almonds'],
#  ['blueberries', 'red wine'],
#  ['blueberries', 'yams'],
#  ['blueberries', 'grated cheese'],
#  ['blueberries', 'french fries'],
#  ['blueberries', 'honey'],
#  ['blueberries', 'salt'],
#  ['blueberries', 'avocado'],
#  ['blueberries', 'tomato juice'],
#  ['blueberries', 'babies food'],
#  ['blueberries', 'barbecue sauce'],
#  ['blueberries', 'tomatoes'],
#  ['blueberries', 'milk'],
#  ['blueberries', 'strong cheese'],
#  ['blueberries', 'shampoo'],
#  ['blueberries', 'bug spray'],
#  ['blueberries', 'salad'],
#  ['blueberries', 'candy bars'],
#  ['blueberries', 'muffins'],
#  ['blueberries', 'green grapes'],
#  ['blueberries', 'mint'],
#  ['blueberries', 'fresh bread'],
#  ['blueberries', 'gums'],
#  ['blueberries', 'shallot'],
#  ['blueberries', 'white wine'],
#  ['blueberries', 'green tea'],
#  ['blueberries', 'champagne'],
#  ['blueberries', 'ham'],
#  ['blueberries', 'escalope'],
#  ['blueberries', 'fresh tuna'],
#  ['blueberries', 'chocolate'],
#  ['blueberries', 'mineral water'],
#  ['blueberries', 'black tea'],
#  ['blueberries', 'frozen smoothie'],
#  ['blueberries', 'shrimp'],
#  ['blueberries', 'soup'],
#  ['blueberries', 'body spray'],
#  ['blueberries', 'chili'],
#  ['blueberries', 'melons'],
#  ['blueberries', 'mayonnaise'],
#  ['blueberries', 'clothes accessories'],
#  ['blueberries', 'soda'],
#  ['blueberries', 'pasta'],
#  ['blueberries', 'flax seed'],
#  ['blueberries', 'bramble'],
#  ['blueberries', 'yogurt cake'],
#  ['blueberries', 'oatmeal'],
#  ['blueberries', 'cake'],
#  ['blueberries', 'low fat yogurt'],
#  ['blueberries', 'mushroom cream sauce'],
#  ['blueberries', ' asparagus'],
#  ['blueberries', 'cottage cheese'],
#  ['blueberries', 'light mayo'],
#  ['blueberries', 'spinach'],
#  ['blueberries', 'cereals'],
#  ['blueberries', 'water spray'],
#  ['blueberries', 'napkins'],
#  ['blueberries', 'french wine'],
#  ['blueberries', 'asparagus'],
#  ['blueberries', 'pet food'],
#  ['blueberries', 'salmon'],
#  ['blueberries', 'tomato sauce'],
#  ['blueberries', 'pickles'],
#  ['blueberries', 'eggplant'],
#  ['blueberries', 'zucchini'],
#  ['blueberries', 'pancakes'],
#  ['blueberries', 'green beans'],
#  ['blueberries', 'ketchup'],
#  ['blueberries', 'fromage blanc'],
#  ['blueberries', 'strawberries'],
#  ['blueberries', 'dessert wine'],
#  ['blueberries', 'cider'],
#  ['blueberries', 'frozen vegetables'],
#  ['blueberries', 'nonfat milk'],
#  ['blueberries', 'meatballs'],
#  ['blueberries', 'butter'],
#  ['blueberries', 'bacon'],
#  ['blueberries', 'turkey'],
#  ['blueberries', 'magazines'],
#  ['blueberries', 'oil'],
#  ['blueberries', 'olive oil'],
#  ['blueberries', 'cauliflower'],
#  ['blueberries', 'herb & pepper'],
#  ['blueberries', 'hand protein bar'],
#  ['blueberries', 'whole wheat pasta'],
#  ['blueberries', 'chocolate bread'],
#  ['blueberries', 'toothpaste'],
#  ['blueberries', 'protein bar'],
#  ['blueberries', 'tea'],
#  ['blueberries', 'chutney'],
#  ['blueberries', 'extra dark chocolate'],
#  ['blueberries', 'hot dogs'],
#  ['blueberries', 'cooking oil'],
#  ['blueberries', 'chicken'],
#  ['blueberries', 'energy drink'],
#  ['burgers', 'sparkling water'],
#  ['burgers', 'burger sauce'],
#  ['burgers', 'brownies'],
#  ['burgers', 'light cream'],
#  ['burgers', 'carrots'],
#  ['burgers', 'antioxydant juice'],
#  ['burgers', 'vegetables mix'],
#  ['burgers', 'sandwich'],
#  ['burgers', 'gluten free bar'],
#  ['burgers', 'rice'],
#  ['burgers', 'whole wheat rice'],
#  ['burgers', 'mint green tea'],
#  ['burgers', 'pepper'],
#  ['burgers', 'parmesan cheese'],
#  ['burgers', 'corn'],
#  ['burgers', 'mashed potato'],
#  ['burgers', 'cookies'],
#  ['burgers', 'energy bar'],
#  ['burgers', 'spaghetti'],
#  ['burgers', 'ground beef'],
#  ['burgers', 'eggs'],
#  ['burgers', 'cream'],
#  ['burgers', 'whole weat flour'],
#  ['burgers', 'almonds'],
#  ['burgers', 'red wine'],
#  ['burgers', 'yams'],
#  ['burgers', 'grated cheese'],
#  ['burgers', 'french fries'],
#  ['burgers', 'honey'],
#  ['burgers', 'salt'],
#  ['burgers', 'avocado'],
#  ['burgers', 'tomato juice'],
#  ['burgers', 'babies food'],
#  ['burgers', 'barbecue sauce'],
#  ['burgers', 'tomatoes'],
#  ['burgers', 'milk'],
#  ['burgers', 'strong cheese'],
#  ['burgers', 'shampoo'],
#  ['burgers', 'bug spray'],
#  ['burgers', 'salad'],
#  ['burgers', 'candy bars'],
#  ['burgers', 'muffins'],
#  ['burgers', 'green grapes'],
#  ['burgers', 'mint'],
#  ['burgers', 'fresh bread'],
#  ['burgers', 'gums'],
#  ['burgers', 'shallot'],
#  ['burgers', 'white wine'],
#  ['burgers', 'green tea'],
#  ['burgers', 'champagne'],
#  ['burgers', 'ham'],
#  ['burgers', 'escalope'],
#  ['burgers', 'fresh tuna'],
#  ['burgers', 'chocolate'],
#  ['burgers', 'mineral water'],
#  ['burgers', 'black tea'],
#  ['burgers', 'frozen smoothie'],
#  ['burgers', 'shrimp'],
#  ['burgers', 'soup'],
#  ['burgers', 'body spray'],
#  ['burgers', 'chili'],
#  ['burgers', 'melons'],
#  ['burgers', 'mayonnaise'],
#  ['burgers', 'clothes accessories'],
#  ['burgers', 'soda'],
#  ['burgers', 'pasta'],
#  ['burgers', 'flax seed'],
#  ['burgers', 'bramble'],
#  ['burgers', 'yogurt cake'],
#  ['burgers', 'oatmeal'],
#  ['burgers', 'cake'],
#  ['burgers', 'low fat yogurt'],
#  ['burgers', 'mushroom cream sauce'],
#  ['burgers', ' asparagus'],
#  ['burgers', 'cottage cheese'],
#  ['burgers', 'light mayo'],
#  ['burgers', 'spinach'],
#  ['burgers', 'cereals'],
#  ['burgers', 'water spray'],
#  ['burgers', 'napkins'],
#  ['burgers', 'french wine'],
#  ['burgers', 'asparagus'],
#  ['burgers', 'pet food'],
#  ['burgers', 'salmon'],
#  ['burgers', 'tomato sauce'],
#  ['burgers', 'pickles'],
#  ['burgers', 'eggplant'],
#  ['burgers', 'zucchini'],
#  ['burgers', 'pancakes'],
#  ['burgers', 'green beans'],
#  ['burgers', 'ketchup'],
#  ['burgers', 'fromage blanc'],
#  ['burgers', 'strawberries'],
#  ['burgers', 'dessert wine'],
#  ['burgers', 'cider'],
#  ['burgers', 'frozen vegetables'],
#  ['burgers', 'nonfat milk'],
#  ['burgers', 'meatballs'],
#  ['burgers', 'butter'],
#  ['burgers', 'bacon'],
#  ['burgers', 'turkey'],
#  ['burgers', 'magazines'],
#  ['burgers', 'oil'],
#  ['burgers', 'olive oil'],
#  ['burgers', 'cauliflower'],
#  ['burgers', 'herb & pepper'],
#  ['burgers', 'hand protein bar'],
#  ['burgers', 'whole wheat pasta'],
#  ['burgers', 'chocolate bread'],
#  ['burgers', 'toothpaste'],
#  ['burgers', 'protein bar'],
#  ['burgers', 'tea'],
#  ['burgers', 'chutney'],
#  ['burgers', 'extra dark chocolate'],
#  ['burgers', 'hot dogs'],
#  ['burgers', 'cooking oil'],
#  ['burgers', 'chicken'],
#  ['burgers', 'energy drink'],
#  ['sparkling water', 'burger sauce'],
#  ['sparkling water', 'brownies'],
#  ['sparkling water', 'light cream'],
#  ['sparkling water', 'carrots'],
#  ['sparkling water', 'antioxydant juice'],
#  ['sparkling water', 'vegetables mix'],
#  ['sparkling water', 'sandwich'],
#  ['sparkling water', 'gluten free bar'],
#  ['sparkling water', 'rice'],
#  ['sparkling water', 'whole wheat rice'],
#  ['sparkling water', 'mint green tea'],
#  ['sparkling water', 'pepper'],
#  ['sparkling water', 'parmesan cheese'],
#  ['sparkling water', 'corn'],
#  ['sparkling water', 'mashed potato'],
#  ['sparkling water', 'cookies'],
#  ['sparkling water', 'energy bar'],
#  ['sparkling water', 'spaghetti'],
#  ['sparkling water', 'ground beef'],
#  ['sparkling water', 'eggs'],
#  ['sparkling water', 'cream'],
#  ['sparkling water', 'whole weat flour'],
#  ['sparkling water', 'almonds'],
#  ['sparkling water', 'red wine'],
#  ['sparkling water', 'yams'],
#  ['sparkling water', 'grated cheese'],
#  ['sparkling water', 'french fries'],
#  ['sparkling water', 'honey'],
#  ['sparkling water', 'salt'],
#  ['sparkling water', 'avocado'],
#  ['sparkling water', 'tomato juice'],
#  ['sparkling water', 'babies food'],
#  ['sparkling water', 'barbecue sauce'],
#  ['sparkling water', 'tomatoes'],
#  ['sparkling water', 'milk'],
#  ['sparkling water', 'strong cheese'],
#  ['sparkling water', 'shampoo'],
#  ['sparkling water', 'bug spray'],
#  ['sparkling water', 'salad'],
#  ['sparkling water', 'candy bars'],
#  ['sparkling water', 'muffins'],
#  ['sparkling water', 'green grapes'],
#  ['sparkling water', 'mint'],
#  ['sparkling water', 'fresh bread'],
#  ['sparkling water', 'gums'],
#  ['sparkling water', 'shallot'],
#  ['sparkling water', 'white wine'],
#  ['sparkling water', 'green tea'],
#  ['sparkling water', 'champagne'],
#  ['sparkling water', 'ham'],
#  ['sparkling water', 'escalope'],
#  ['sparkling water', 'fresh tuna'],
#  ['sparkling water', 'chocolate'],
#  ['sparkling water', 'mineral water'],
#  ['sparkling water', 'black tea'],
#  ['sparkling water', 'frozen smoothie'],
#  ['sparkling water', 'shrimp'],
#  ['sparkling water', 'soup'],
#  ['sparkling water', 'body spray'],
#  ['sparkling water', 'chili'],
#  ['sparkling water', 'melons'],
#  ['sparkling water', 'mayonnaise'],
#  ['sparkling water', 'clothes accessories'],
#  ['sparkling water', 'soda'],
#  ['sparkling water', 'pasta'],
#  ['sparkling water', 'flax seed'],
#  ['sparkling water', 'bramble'],
#  ['sparkling water', 'yogurt cake'],
#  ['sparkling water', 'oatmeal'],
#  ['sparkling water', 'cake'],
#  ['sparkling water', 'low fat yogurt'],
#  ['sparkling water', 'mushroom cream sauce'],
#  ['sparkling water', ' asparagus'],
#  ['sparkling water', 'cottage cheese'],
#  ['sparkling water', 'light mayo'],
#  ['sparkling water', 'spinach'],
#  ['sparkling water', 'cereals'],
#  ['sparkling water', 'water spray'],
#  ['sparkling water', 'napkins'],
#  ['sparkling water', 'french wine'],
#  ['sparkling water', 'asparagus'],
#  ['sparkling water', 'pet food'],
#  ['sparkling water', 'salmon'],
#  ['sparkling water', 'tomato sauce'],
#  ['sparkling water', 'pickles'],
#  ['sparkling water', 'eggplant'],
#  ['sparkling water', 'zucchini'],
#  ['sparkling water', 'pancakes'],
#  ['sparkling water', 'green beans'],
#  ['sparkling water', 'ketchup'],
#  ['sparkling water', 'fromage blanc'],
#  ['sparkling water', 'strawberries'],
#  ['sparkling water', 'dessert wine'],
#  ['sparkling water', 'cider'],
#  ['sparkling water', 'frozen vegetables'],
#  ['sparkling water', 'nonfat milk'],
#  ['sparkling water', 'meatballs'],
#  ['sparkling water', 'butter'],
#  ['sparkling water', 'bacon'],
#  ['sparkling water', 'turkey'],
#  ['sparkling water', 'magazines'],
#  ['sparkling water', 'oil'],
#  ['sparkling water', 'olive oil'],
#  ['sparkling water', 'cauliflower'],
#  ['sparkling water', 'herb & pepper'],
#  ['sparkling water', 'hand protein bar'],
#  ['sparkling water', 'whole wheat pasta'],
#  ['sparkling water', 'chocolate bread'],
#  ['sparkling water', 'toothpaste'],
#  ['sparkling water', 'protein bar'],
#  ['sparkling water', 'tea'],
#  ['sparkling water', 'chutney'],
#  ['sparkling water', 'extra dark chocolate'],
#  ['sparkling water', 'hot dogs'],
#  ['sparkling water', 'cooking oil'],
#  ['sparkling water', 'chicken'],
#  ['sparkling water', 'energy drink'],
#  ['burger sauce', 'brownies'],
#  ['burger sauce', 'light cream'],
#  ['burger sauce', 'carrots'],
#  ['burger sauce', 'antioxydant juice'],
#  ['burger sauce', 'vegetables mix'],
#  ['burger sauce', 'sandwich'],
#  ['burger sauce', 'gluten free bar'],
#  ['burger sauce', 'rice'],
#  ['burger sauce', 'whole wheat rice'],
#  ['burger sauce', 'mint green tea'],
#  ['burger sauce', 'pepper'],
#  ['burger sauce', 'parmesan cheese'],
#  ['burger sauce', 'corn'],
#  ['burger sauce', 'mashed potato'],
#  ['burger sauce', 'cookies'],
#  ['burger sauce', 'energy bar'],
#  ['burger sauce', 'spaghetti'],
#  ['burger sauce', 'ground beef'],
#  ['burger sauce', 'eggs'],
#  ['burger sauce', 'cream'],
#  ['burger sauce', 'whole weat flour'],
#  ['burger sauce', 'almonds'],
#  ['burger sauce', 'red wine'],
#  ['burger sauce', 'yams'],
#  ['burger sauce', 'grated cheese'],
#  ['burger sauce', 'french fries'],
#  ['burger sauce', 'honey'],
#  ['burger sauce', 'salt'],
#  ['burger sauce', 'avocado'],
#  ['burger sauce', 'tomato juice'],
#  ['burger sauce', 'babies food'],
#  ['burger sauce', 'barbecue sauce'],
#  ['burger sauce', 'tomatoes'],
#  ['burger sauce', 'milk'],
#  ['burger sauce', 'strong cheese'],
#  ['burger sauce', 'shampoo'],
#  ['burger sauce', 'bug spray'],
#  ['burger sauce', 'salad'],
#  ['burger sauce', 'candy bars'],
#  ['burger sauce', 'muffins'],
#  ['burger sauce', 'green grapes'],
#  ['burger sauce', 'mint'],
#  ['burger sauce', 'fresh bread'],
#  ['burger sauce', 'gums'],
#  ['burger sauce', 'shallot'],
#  ['burger sauce', 'white wine'],
#  ['burger sauce', 'green tea'],
#  ['burger sauce', 'champagne'],
#  ['burger sauce', 'ham'],
#  ['burger sauce', 'escalope'],
#  ['burger sauce', 'fresh tuna'],
#  ['burger sauce', 'chocolate'],
#  ['burger sauce', 'mineral water'],
#  ['burger sauce', 'black tea'],
#  ['burger sauce', 'frozen smoothie'],
#  ['burger sauce', 'shrimp'],
#  ['burger sauce', 'soup'],
#  ['burger sauce', 'body spray'],
#  ['burger sauce', 'chili'],
#  ['burger sauce', 'melons'],
#  ['burger sauce', 'mayonnaise'],
#  ['burger sauce', 'clothes accessories'],
#  ['burger sauce', 'soda'],
#  ['burger sauce', 'pasta'],
#  ['burger sauce', 'flax seed'],
#  ['burger sauce', 'bramble'],
#  ['burger sauce', 'yogurt cake'],
#  ['burger sauce', 'oatmeal'],
#  ['burger sauce', 'cake'],
#  ['burger sauce', 'low fat yogurt'],
#  ['burger sauce', 'mushroom cream sauce'],
#  ['burger sauce', ' asparagus'],
#  ['burger sauce', 'cottage cheese'],
#  ['burger sauce', 'light mayo'],
#  ['burger sauce', 'spinach'],
#  ['burger sauce', 'cereals'],
#  ['burger sauce', 'water spray'],
#  ['burger sauce', 'napkins'],
#  ['burger sauce', 'french wine'],
#  ['burger sauce', 'asparagus'],
#  ['burger sauce', 'pet food'],
#  ['burger sauce', 'salmon'],
#  ['burger sauce', 'tomato sauce'],
#  ['burger sauce', 'pickles'],
#  ['burger sauce', 'eggplant'],
#  ['burger sauce', 'zucchini'],
#  ['burger sauce', 'pancakes'],
#  ['burger sauce', 'green beans'],
#  ['burger sauce', 'ketchup'],
#  ['burger sauce', 'fromage blanc'],
#  ['burger sauce', 'strawberries'],
#  ['burger sauce', 'dessert wine'],
#  ['burger sauce', 'cider'],
#  ['burger sauce', 'frozen vegetables'],
#  ['burger sauce', 'nonfat milk'],
#  ['burger sauce', 'meatballs'],
#  ['burger sauce', 'butter'],
#  ['burger sauce', 'bacon'],
#  ['burger sauce', 'turkey'],
#  ['burger sauce', 'magazines'],
#  ['burger sauce', 'oil'],
#  ['burger sauce', 'olive oil'],
#  ['burger sauce', 'cauliflower'],
#  ['burger sauce', 'herb & pepper'],
#  ['burger sauce', 'hand protein bar'],
#  ['burger sauce', 'whole wheat pasta'],
#  ['burger sauce', 'chocolate bread'],
#  ['burger sauce', 'toothpaste'],
#  ['burger sauce', 'protein bar'],
#  ['burger sauce', 'tea'],
#  ['burger sauce', 'chutney'],
#  ['burger sauce', 'extra dark chocolate'],
#  ['burger sauce', 'hot dogs'],
#  ['burger sauce', 'cooking oil'],
#  ['burger sauce', 'chicken'],
#  ['burger sauce', 'energy drink'],
#  ['brownies', 'light cream'],
#  ['brownies', 'carrots'],
#  ['brownies', 'antioxydant juice'],
#  ['brownies', 'vegetables mix'],
#  ['brownies', 'sandwich'],
#  ['brownies', 'gluten free bar'],
#  ['brownies', 'rice'],
#  ['brownies', 'whole wheat rice'],
#  ['brownies', 'mint green tea'],
#  ['brownies', 'pepper'],
#  ['brownies', 'parmesan cheese'],
#  ['brownies', 'corn'],
#  ['brownies', 'mashed potato'],
#  ['brownies', 'cookies'],
#  ['brownies', 'energy bar'],
#  ['brownies', 'spaghetti'],
#  ['brownies', 'ground beef'],
#  ['brownies', 'eggs'],
#  ['brownies', 'cream'],
#  ['brownies', 'whole weat flour'],
#  ['brownies', 'almonds'],
#  ['brownies', 'red wine'],
#  ['brownies', 'yams'],
#  ['brownies', 'grated cheese'],
#  ['brownies', 'french fries'],
#  ['brownies', 'honey'],
#  ['brownies', 'salt'],
#  ['brownies', 'avocado'],
#  ['brownies', 'tomato juice'],
#  ['brownies', 'babies food'],
#  ['brownies', 'barbecue sauce'],
#  ['brownies', 'tomatoes'],
#  ['brownies', 'milk'],
#  ['brownies', 'strong cheese'],
#  ['brownies', 'shampoo'],
#  ['brownies', 'bug spray'],
#  ['brownies', 'salad'],
#  ['brownies', 'candy bars'],
#  ['brownies', 'muffins'],
#  ['brownies', 'green grapes'],
#  ['brownies', 'mint'],
#  ['brownies', 'fresh bread'],
#  ['brownies', 'gums'],
#  ['brownies', 'shallot'],
#  ['brownies', 'white wine'],
#  ['brownies', 'green tea'],
#  ['brownies', 'champagne'],
#  ['brownies', 'ham'],
#  ['brownies', 'escalope'],
#  ['brownies', 'fresh tuna'],
#  ['brownies', 'chocolate'],
#  ['brownies', 'mineral water'],
#  ['brownies', 'black tea'],
#  ['brownies', 'frozen smoothie'],
#  ['brownies', 'shrimp'],
#  ['brownies', 'soup'],
#  ['brownies', 'body spray'],
#  ['brownies', 'chili'],
#  ['brownies', 'melons'],
#  ['brownies', 'mayonnaise'],
#  ['brownies', 'clothes accessories'],
#  ['brownies', 'soda'],
#  ['brownies', 'pasta'],
#  ['brownies', 'flax seed'],
#  ['brownies', 'bramble'],
#  ['brownies', 'yogurt cake'],
#  ['brownies', 'oatmeal'],
#  ['brownies', 'cake'],
#  ['brownies', 'low fat yogurt'],
#  ['brownies', 'mushroom cream sauce'],
#  ['brownies', ' asparagus'],
#  ['brownies', 'cottage cheese'],
#  ['brownies', 'light mayo'],
#  ['brownies', 'spinach'],
#  ['brownies', 'cereals'],
#  ['brownies', 'water spray'],
#  ['brownies', 'napkins'],
#  ['brownies', 'french wine'],
#  ['brownies', 'asparagus'],
#  ['brownies', 'pet food'],
#  ['brownies', 'salmon'],
#  ['brownies', 'tomato sauce'],
#  ['brownies', 'pickles'],
#  ['brownies', 'eggplant'],
#  ['brownies', 'zucchini'],
#  ['brownies', 'pancakes'],
#  ['brownies', 'green beans'],
#  ['brownies', 'ketchup'],
#  ['brownies', 'fromage blanc'],
#  ['brownies', 'strawberries'],
#  ['brownies', 'dessert wine'],
#  ['brownies', 'cider'],
#  ['brownies', 'frozen vegetables'],
#  ['brownies', 'nonfat milk'],
#  ['brownies', 'meatballs'],
#  ['brownies', 'butter'],
#  ['brownies', 'bacon'],
#  ['brownies', 'turkey'],
#  ['brownies', 'magazines'],
#  ['brownies', 'oil'],
#  ['brownies', 'olive oil'],
#  ['brownies', 'cauliflower'],
#  ['brownies', 'herb & pepper'],
#  ['brownies', 'hand protein bar'],
#  ['brownies', 'whole wheat pasta'],
#  ['brownies', 'chocolate bread'],
#  ['brownies', 'toothpaste'],
#  ['brownies', 'protein bar'],
#  ['brownies', 'tea'],
#  ['brownies', 'chutney'],
#  ['brownies', 'extra dark chocolate'],
#  ['brownies', 'hot dogs'],
#  ['brownies', 'cooking oil'],
#  ['brownies', 'chicken'],
#  ['brownies', 'energy drink'],
#  ['light cream', 'carrots'],
#  ['light cream', 'antioxydant juice'],
#  ['light cream', 'vegetables mix'],
#  ['light cream', 'sandwich'],
#  ['light cream', 'gluten free bar'],
#  ['light cream', 'rice'],
#  ['light cream', 'whole wheat rice'],
#  ['light cream', 'mint green tea'],
#  ['light cream', 'pepper'],
#  ['light cream', 'parmesan cheese'],
#  ['light cream', 'corn'],
#  ['light cream', 'mashed potato'],
#  ['light cream', 'cookies'],
#  ['light cream', 'energy bar'],
#  ['light cream', 'spaghetti'],
#  ['light cream', 'ground beef'],
#  ['light cream', 'eggs'],
#  ['light cream', 'cream'],
#  ['light cream', 'whole weat flour'],
#  ['light cream', 'almonds'],
#  ['light cream', 'red wine'],
#  ['light cream', 'yams'],
#  ['light cream', 'grated cheese'],
#  ['light cream', 'french fries'],
#  ['light cream', 'honey'],
#  ['light cream', 'salt'],
#  ['light cream', 'avocado'],
#  ['light cream', 'tomato juice'],
#  ['light cream', 'babies food'],
#  ['light cream', 'barbecue sauce'],
#  ['light cream', 'tomatoes'],
#  ['light cream', 'milk'],
#  ['light cream', 'strong cheese'],
#  ['light cream', 'shampoo'],
#  ['light cream', 'bug spray'],
#  ['light cream', 'salad'],
#  ['light cream', 'candy bars'],
#  ['light cream', 'muffins'],
#  ['light cream', 'green grapes'],
#  ['light cream', 'mint'],
#  ['light cream', 'fresh bread'],
#  ['light cream', 'gums'],
#  ['light cream', 'shallot'],
#  ['light cream', 'white wine'],
#  ['light cream', 'green tea'],
#  ['light cream', 'champagne'],
#  ['light cream', 'ham'],
#  ['light cream', 'escalope'],
#  ['light cream', 'fresh tuna'],
#  ['light cream', 'chocolate'],
#  ['light cream', 'mineral water'],
#  ['light cream', 'black tea'],
#  ['light cream', 'frozen smoothie'],
#  ['light cream', 'shrimp'],
#  ['light cream', 'soup'],
#  ['light cream', 'body spray'],
#  ['light cream', 'chili'],
#  ['light cream', 'melons'],
#  ['light cream', 'mayonnaise'],
#  ['light cream', 'clothes accessories'],
#  ['light cream', 'soda'],
#  ['light cream', 'pasta'],
#  ['light cream', 'flax seed'],
#  ['light cream', 'bramble'],
#  ['light cream', 'yogurt cake'],
#  ['light cream', 'oatmeal'],
#  ['light cream', 'cake'],
#  ['light cream', 'low fat yogurt'],
#  ['light cream', 'mushroom cream sauce'],
#  ['light cream', ' asparagus'],
#  ['light cream', 'cottage cheese'],
#  ['light cream', 'light mayo'],
#  ['light cream', 'spinach'],
#  ['light cream', 'cereals'],
#  ['light cream', 'water spray'],
#  ['light cream', 'napkins'],
#  ['light cream', 'french wine'],
#  ['light cream', 'asparagus'],
#  ['light cream', 'pet food'],
#  ['light cream', 'salmon'],
#  ['light cream', 'tomato sauce'],
#  ['light cream', 'pickles'],
#  ['light cream', 'eggplant'],
#  ['light cream', 'zucchini'],
#  ['light cream', 'pancakes'],
#  ['light cream', 'green beans'],
#  ['light cream', 'ketchup'],
#  ['light cream', 'fromage blanc'],
#  ['light cream', 'strawberries'],
#  ['light cream', 'dessert wine'],
#  ['light cream', 'cider'],
#  ['light cream', 'frozen vegetables'],
#  ['light cream', 'nonfat milk'],
#  ['light cream', 'meatballs'],
#  ['light cream', 'butter'],
#  ['light cream', 'bacon'],
#  ['light cream', 'turkey'],
#  ['light cream', 'magazines'],
#  ['light cream', 'oil'],
#  ['light cream', 'olive oil'],
#  ['light cream', 'cauliflower'],
#  ['light cream', 'herb & pepper'],
#  ['light cream', 'hand protein bar'],
#  ['light cream', 'whole wheat pasta'],
#  ['light cream', 'chocolate bread'],
#  ['light cream', 'toothpaste'],
#  ['light cream', 'protein bar'],
#  ['light cream', 'tea'],
#  ['light cream', 'chutney'],
#  ['light cream', 'extra dark chocolate'],
#  ['light cream', 'hot dogs'],
#  ['light cream', 'cooking oil'],
#  ['light cream', 'chicken'],
#  ['light cream', 'energy drink'],
#  ['carrots', 'antioxydant juice'],
#  ['carrots', 'vegetables mix'],
#  ['carrots', 'sandwich'],
#  ['carrots', 'gluten free bar'],
#  ['carrots', 'rice'],
#  ['carrots', 'whole wheat rice'],
#  ['carrots', 'mint green tea'],
#  ['carrots', 'pepper'],
#  ['carrots', 'parmesan cheese'],
#  ['carrots', 'corn'],
#  ['carrots', 'mashed potato'],
#  ['carrots', 'cookies'],
#  ['carrots', 'energy bar'],
#  ['carrots', 'spaghetti'],
#  ['carrots', 'ground beef'],
#  ['carrots', 'eggs'],
#  ['carrots', 'cream'],
#  ['carrots', 'whole weat flour'],
#  ['carrots', 'almonds'],
#  ['carrots', 'red wine'],
#  ['carrots', 'yams'],
#  ['carrots', 'grated cheese'],
#  ['carrots', 'french fries'],
#  ['carrots', 'honey'],
#  ['carrots', 'salt'],
#  ['carrots', 'avocado'],
#  ['carrots', 'tomato juice'],
#  ['carrots', 'babies food'],
#  ['carrots', 'barbecue sauce'],
#  ['carrots', 'tomatoes'],
#  ['carrots', 'milk'],
#  ['carrots', 'strong cheese'],
#  ['carrots', 'shampoo'],
#  ['carrots', 'bug spray'],
#  ['carrots', 'salad'],
#  ['carrots', 'candy bars'],
#  ['carrots', 'muffins'],
#  ['carrots', 'green grapes'],
#  ['carrots', 'mint'],
#  ['carrots', 'fresh bread'],
#  ['carrots', 'gums'],
#  ['carrots', 'shallot'],
#  ['carrots', 'white wine'],
#  ['carrots', 'green tea'],
#  ['carrots', 'champagne'],
#  ['carrots', 'ham'],
#  ['carrots', 'escalope'],
#  ['carrots', 'fresh tuna'],
#  ['carrots', 'chocolate'],
#  ['carrots', 'mineral water'],
#  ['carrots', 'black tea'],
#  ['carrots', 'frozen smoothie'],
#  ['carrots', 'shrimp'],
#  ['carrots', 'soup'],
#  ['carrots', 'body spray'],
#  ['carrots', 'chili'],
#  ['carrots', 'melons'],
#  ['carrots', 'mayonnaise'],
#  ['carrots', 'clothes accessories'],
#  ['carrots', 'soda'],
#  ['carrots', 'pasta'],
#  ['carrots', 'flax seed'],
#  ['carrots', 'bramble'],
#  ['carrots', 'yogurt cake'],
#  ['carrots', 'oatmeal'],
#  ['carrots', 'cake'],
#  ['carrots', 'low fat yogurt'],
#  ['carrots', 'mushroom cream sauce'],
#  ['carrots', ' asparagus'],
#  ['carrots', 'cottage cheese'],
#  ['carrots', 'light mayo'],
#  ['carrots', 'spinach'],
#  ['carrots', 'cereals'],
#  ['carrots', 'water spray'],
#  ['carrots', 'napkins'],
#  ['carrots', 'french wine'],
#  ['carrots', 'asparagus'],
#  ['carrots', 'pet food'],
#  ['carrots', 'salmon'],
#  ['carrots', 'tomato sauce'],
#  ['carrots', 'pickles'],
#  ['carrots', 'eggplant'],
#  ['carrots', 'zucchini'],
#  ['carrots', 'pancakes'],
#  ['carrots', 'green beans'],
#  ['carrots', 'ketchup'],
#  ['carrots', 'fromage blanc'],
#  ['carrots', 'strawberries'],
#  ['carrots', 'dessert wine'],
#  ['carrots', 'cider'],
#  ['carrots', 'frozen vegetables'],
#  ['carrots', 'nonfat milk'],
#  ['carrots', 'meatballs'],
#  ['carrots', 'butter'],
#  ['carrots', 'bacon'],
#  ['carrots', 'turkey'],
#  ['carrots', 'magazines'],
#  ['carrots', 'oil'],
#  ['carrots', 'olive oil'],
#  ['carrots', 'cauliflower'],
#  ['carrots', 'herb & pepper'],
#  ['carrots', 'hand protein bar'],
#  ['carrots', 'whole wheat pasta'],
#  ['carrots', 'chocolate bread'],
#  ['carrots', 'toothpaste'],
#  ['carrots', 'protein bar'],
#  ['carrots', 'tea'],
#  ['carrots', 'chutney'],
#  ['carrots', 'extra dark chocolate'],
#  ['carrots', 'hot dogs'],
#  ['carrots', 'cooking oil'],
#  ['carrots', 'chicken'],
#  ['carrots', 'energy drink'],
#  ['antioxydant juice', 'vegetables mix'],
#  ['antioxydant juice', 'sandwich'],
#  ['antioxydant juice', 'gluten free bar'],
#  ['antioxydant juice', 'rice'],
#  ['antioxydant juice', 'whole wheat rice'],
#  ['antioxydant juice', 'mint green tea'],
#  ['antioxydant juice', 'pepper'],
#  ['antioxydant juice', 'parmesan cheese'],
#  ['antioxydant juice', 'corn'],
#  ['antioxydant juice', 'mashed potato'],
#  ['antioxydant juice', 'cookies'],
#  ['antioxydant juice', 'energy bar'],
#  ['antioxydant juice', 'spaghetti'],
#  ['antioxydant juice', 'ground beef'],
#  ['antioxydant juice', 'eggs'],
#  ['antioxydant juice', 'cream'],
#  ['antioxydant juice', 'whole weat flour'],
#  ['antioxydant juice', 'almonds'],
#  ['antioxydant juice', 'red wine'],
#  ['antioxydant juice', 'yams'],
#  ['antioxydant juice', 'grated cheese'],
#  ['antioxydant juice', 'french fries'],
#  ['antioxydant juice', 'honey'],
#  ['antioxydant juice', 'salt'],
#  ['antioxydant juice', 'avocado'],
#  ['antioxydant juice', 'tomato juice'],
#  ['antioxydant juice', 'babies food'],
#  ['antioxydant juice', 'barbecue sauce'],
#  ['antioxydant juice', 'tomatoes'],
#  ['antioxydant juice', 'milk'],
#  ['antioxydant juice', 'strong cheese'],
#  ['antioxydant juice', 'shampoo'],
#  ['antioxydant juice', 'bug spray'],
#  ['antioxydant juice', 'salad'],
#  ['antioxydant juice', 'candy bars'],
#  ['antioxydant juice', 'muffins'],
#  ['antioxydant juice', 'green grapes'],
#  ['antioxydant juice', 'mint'],
#  ['antioxydant juice', 'fresh bread'],
#  ['antioxydant juice', 'gums'],
#  ['antioxydant juice', 'shallot'],
#  ['antioxydant juice', 'white wine'],
#  ['antioxydant juice', 'green tea'],
#  ['antioxydant juice', 'champagne'],
#  ['antioxydant juice', 'ham'],
#  ['antioxydant juice', 'escalope'],
#  ['antioxydant juice', 'fresh tuna'],
#  ['antioxydant juice', 'chocolate'],
#  ['antioxydant juice', 'mineral water'],
#  ['antioxydant juice', 'black tea'],
#  ['antioxydant juice', 'frozen smoothie'],
#  ['antioxydant juice', 'shrimp'],
#  ['antioxydant juice', 'soup'],
#  ['antioxydant juice', 'body spray'],
#  ['antioxydant juice', 'chili'],
#  ['antioxydant juice', 'melons'],
#  ['antioxydant juice', 'mayonnaise'],
#  ['antioxydant juice', 'clothes accessories'],
#  ['antioxydant juice', 'soda'],
#  ['antioxydant juice', 'pasta'],
#  ['antioxydant juice', 'flax seed'],
#  ['antioxydant juice', 'bramble'],
#  ['antioxydant juice', 'yogurt cake'],
#  ['antioxydant juice', 'oatmeal'],
#  ['antioxydant juice', 'cake'],
#  ['antioxydant juice', 'low fat yogurt'],
#  ['antioxydant juice', 'mushroom cream sauce'],
#  ['antioxydant juice', ' asparagus'],
#  ['antioxydant juice', 'cottage cheese'],
#  ['antioxydant juice', 'light mayo'],
#  ['antioxydant juice', 'spinach'],
#  ['antioxydant juice', 'cereals'],
#  ['antioxydant juice', 'water spray'],
#  ['antioxydant juice', 'napkins'],
#  ['antioxydant juice', 'french wine'],
#  ['antioxydant juice', 'asparagus'],
#  ['antioxydant juice', 'pet food'],
#  ['antioxydant juice', 'salmon'],
#  ['antioxydant juice', 'tomato sauce'],
#  ['antioxydant juice', 'pickles'],
#  ['antioxydant juice', 'eggplant'],
#  ['antioxydant juice', 'zucchini'],
#  ['antioxydant juice', 'pancakes'],
#  ['antioxydant juice', 'green beans'],
#  ['antioxydant juice', 'ketchup'],
#  ['antioxydant juice', 'fromage blanc'],
#  ['antioxydant juice', 'strawberries'],
#  ['antioxydant juice', 'dessert wine'],
#  ['antioxydant juice', 'cider'],
#  ['antioxydant juice', 'frozen vegetables'],
#  ['antioxydant juice', 'nonfat milk'],
#  ['antioxydant juice', 'meatballs'],
#  ['antioxydant juice', 'butter'],
#  ['antioxydant juice', 'bacon'],
#  ['antioxydant juice', 'turkey'],
#  ['antioxydant juice', 'magazines'],
#  ['antioxydant juice', 'oil'],
#  ['antioxydant juice', 'olive oil'],
#  ['antioxydant juice', 'cauliflower'],
#  ['antioxydant juice', 'herb & pepper'],
#  ['antioxydant juice', 'hand protein bar'],
#  ['antioxydant juice', 'whole wheat pasta'],
#  ['antioxydant juice', 'chocolate bread'],
#  ['antioxydant juice', 'toothpaste'],
#  ['antioxydant juice', 'protein bar'],
#  ['antioxydant juice', 'tea'],
#  ['antioxydant juice', 'chutney'],
#  ['antioxydant juice', 'extra dark chocolate'],
#  ['antioxydant juice', 'hot dogs'],
#  ['antioxydant juice', 'cooking oil'],
#  ['antioxydant juice', 'chicken'],
#  ['antioxydant juice', 'energy drink'],
#  ['vegetables mix', 'sandwich'],
#  ['vegetables mix', 'gluten free bar'],
#  ['vegetables mix', 'rice'],
#  ['vegetables mix', 'whole wheat rice'],
#  ['vegetables mix', 'mint green tea'],
#  ['vegetables mix', 'pepper'],
#  ['vegetables mix', 'parmesan cheese'],
#  ['vegetables mix', 'corn'],
#  ['vegetables mix', 'mashed potato'],
#  ['vegetables mix', 'cookies'],
#  ['vegetables mix', 'energy bar'],
#  ['vegetables mix', 'spaghetti'],
#  ['vegetables mix', 'ground beef'],
#  ['vegetables mix', 'eggs'],
#  ['vegetables mix', 'cream'],
#  ['vegetables mix', 'whole weat flour'],
#  ['vegetables mix', 'almonds'],
#  ['vegetables mix', 'red wine'],
#  ['vegetables mix', 'yams'],
#  ['vegetables mix', 'grated cheese'],
#  ['vegetables mix', 'french fries'],
#  ['vegetables mix', 'honey'],
#  ['vegetables mix', 'salt'],
#  ['vegetables mix', 'avocado'],
#  ['vegetables mix', 'tomato juice'],
#  ['vegetables mix', 'babies food'],
#  ['vegetables mix', 'barbecue sauce'],
#  ['vegetables mix', 'tomatoes'],
#  ['vegetables mix', 'milk'],
#  ['vegetables mix', 'strong cheese'],
#  ['vegetables mix', 'shampoo'],
#  ['vegetables mix', 'bug spray'],
#  ['vegetables mix', 'salad'],
#  ['vegetables mix', 'candy bars'],
#  ['vegetables mix', 'muffins'],
#  ['vegetables mix', 'green grapes'],
#  ['vegetables mix', 'mint'],
#  ['vegetables mix', 'fresh bread'],
#  ['vegetables mix', 'gums'],
#  ['vegetables mix', 'shallot'],
#  ['vegetables mix', 'white wine'],
#  ['vegetables mix', 'green tea'],
#  ['vegetables mix', 'champagne'],
#  ['vegetables mix', 'ham'],
#  ['vegetables mix', 'escalope'],
#  ['vegetables mix', 'fresh tuna'],
#  ['vegetables mix', 'chocolate'],
#  ['vegetables mix', 'mineral water'],
#  ['vegetables mix', 'black tea'],
#  ['vegetables mix', 'frozen smoothie'],
#  ['vegetables mix', 'shrimp'],
#  ['vegetables mix', 'soup'],
#  ['vegetables mix', 'body spray'],
#  ['vegetables mix', 'chili'],
#  ['vegetables mix', 'melons'],
#  ['vegetables mix', 'mayonnaise'],
#  ['vegetables mix', 'clothes accessories'],
#  ['vegetables mix', 'soda'],
#  ['vegetables mix', 'pasta'],
#  ['vegetables mix', 'flax seed'],
#  ['vegetables mix', 'bramble'],
#  ['vegetables mix', 'yogurt cake'],
#  ['vegetables mix', 'oatmeal'],
#  ['vegetables mix', 'cake'],
#  ['vegetables mix', 'low fat yogurt'],
#  ['vegetables mix', 'mushroom cream sauce'],
#  ['vegetables mix', ' asparagus'],
#  ['vegetables mix', 'cottage cheese'],
#  ['vegetables mix', 'light mayo'],
#  ['vegetables mix', 'spinach'],
#  ['vegetables mix', 'cereals'],
#  ['vegetables mix', 'water spray'],
#  ['vegetables mix', 'napkins'],
#  ['vegetables mix', 'french wine'],
#  ['vegetables mix', 'asparagus'],
#  ['vegetables mix', 'pet food'],
#  ...]

# %%
#Calculating Score for each Item-pairs...
score=[]
for i in pairs:
    cond=[]
    for item in i:
        cond.append('("%s") in s' %item)
    x = ('[s for s in groceries if ' + ' and '.join(cond) + ']')    
    score.append(len(eval(x))/7501)

# %%
Eclat_results = pd.DataFrame([pairs, score]).T
Eclat_results.columns = ['Pairs', 'Score']

# %%
Eclat_results.sort_values('Score',ascending=False).head(10)
# Out:
#                                    Pairs      Score
# 2225          [spaghetti, mineral water]  0.0597254
# 5060          [chocolate, mineral water]  0.0519931
# 2420               [eggs, mineral water]  0.0501266
# 3755               [milk, mineral water]  0.0479936
# 2323        [ground beef, mineral water]  0.0409279
# 2190            [spaghetti, ground beef]  0.0391948
# 2224              [spaghetti, chocolate]  0.0378616
# 2191                   [spaghetti, eggs]  0.0358619
# 5164  [mineral water, frozen vegetables]  0.0357286
# 2206                   [spaghetti, milk]  0.0354619
